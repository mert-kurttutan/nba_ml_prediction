# %%
# libraries for numerical and data processing
import pandas as pd
import numpy as np


# ML-specific libraries
import xgboost as xgb
import optuna
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler


# libraries for visualization
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt


# helpful util libraries
import random
import json
import os
import joblib
from datetime import datetime, timedelta
from functools import partial


pd.set_option("display.max_columns", 500)


TEMP_DATA_DIR = "temp_data"
TRANSFORMED_DATA_DIR = "transformed_data"
TRANSFORMED_DATA_DIR_v2 = "transformed_data_v2"
GAMELOG_DIR = "gamelog_data"
GAME_ROTATION_DIR = "game_rotation_data"
TEAM_STAT_DIR = "team_stat_data"
PLAYER_STAT_DIR = "player_stat_data"
TRAINING_DIR = "training_data"
TRAINING_DIR_v2 = "training_data_v2"


BUCKET = "mert-kurttutan-nba-project-v1"
BUCKET_TRANSFORMED = "mert-kurttutan-nba-project-transformed-data-v1"

cols_to_drop = ["team1_TEAM_NAME", "team1_TEAM_ID", "team2_TEAM_NAME", "team2_TEAM_ID", 
                "team1_L", "team2_W", "team2_L", "team1_PLUS_MINUS", "team1_PTS", 
                "team2_PLUS_MINUS", "team2_PTS", "team2_IS_HOME"]


cols_to_drop_v2 = ["team1_TEAM_ID", "team2_TEAM_ID", 
                "team1_L", "team2_W", "team2_L", "team1_PLUS_MINUS", "team1_PTS", 
                "team2_PLUS_MINUS", "team2_PTS", "team2_IS_HOME"]

training_files_sorted = sorted([gamelog_file for gamelog_file in os.listdir(f"../../data/{TRANSFORMED_DATA_DIR_v2}/{TRAINING_DIR}")])

training_files_v2_sorted = sorted([gamelog_file for gamelog_file in os.listdir(f"../../data/{TRANSFORMED_DATA_DIR_v2}/{TRAINING_DIR_v2}")])

# %%
df_train_arr = []
for idx, train_file in enumerate(training_files_sorted):
    if not ".csv" in train_file:
        continue


    df_gamelog = pd.read_csv(f"../../data/{TRANSFORMED_DATA_DIR_v2}/{TRAINING_DIR}/{train_file}")
    df_gamelog = df_gamelog.drop(columns=cols_to_drop).sort_values(by=["DATE_WITHIN_SEASON"])

    if idx%2 == 0:
      df_gamelog["SEASON"] = idx+1

    else:
      df_gamelog["SEASON"] = idx-1
    
    # Append data of current season into total data
    df_train_arr.append(df_gamelog)


# Get rid of stat of the very early time
# We could not fill this since there is no previos timeline to use
df_train_arr[1] = df_train_arr[1].loc[~df_train_arr[1]["team2_lag08_AST"].isna(), :]

# %%
df_train_arr_v2 = []
for idx, train_file in enumerate(training_files_v2_sorted):
    if not ".csv" in train_file:
        continue
    df_gamelog = pd.read_csv(f"../../data/{TRANSFORMED_DATA_DIR_v2}/{TRAINING_DIR_v2}/{train_file}")
    df_gamelog = df_gamelog.drop(columns=cols_to_drop_v2).sort_values(by=["DATE_WITHIN_SEASON"])



    if idx%2 == 0:
      df_gamelog["SEASON"] = idx+1

    else:
      df_gamelog["SEASON"] = idx-1
    
    # Append data of current season into total data
    df_train_arr_v2.append(df_gamelog)


# Get rid of stat of the very early time
# We could not fill this since there is no previos timeline to use
df_train_arr_v2[1] = df_train_arr_v2[1].loc[~df_train_arr_v2[1]["team2_lag08_AST"].isna(), :]

# %%
df_train_arr[-1]
# Out:
#       DATE_WITHIN_SEASON   GAME_DATE  IS_REGULAR  team1_IS_HOME  team1_L_cum  \
# 0                      0  2021-10-19           1              1          0.0
# 1                      0  2021-10-19           1              0          0.0
# 12                     1  2021-10-20           1              1          0.0
# 11                     1  2021-10-20           1              0          0.0
# 9                      1  2021-10-20           1              0          0.0
# ...                  ...         ...         ...            ...          ...
# 1216                 173  2022-04-10           1              0          2.0
# 1215                 173  2022-04-10           1              1          0.0
# 1228                 173  2022-04-10           1              1          1.0
# 1221                 173  2022-04-10           1              1          1.0
# 1229                 173  2022-04-10           1              1          3.0
#
#       team1_W  team1_W_cum  team1_lag08_AST  team1_lag08_BLK  \
# 0           1          0.0             0.29             0.10
# 1           1          0.0             0.54             0.08
# 12          0          0.0             0.50             0.13
# 11          1          0.0             0.42             0.04
# 9           0          0.0             0.48             0.06
# ...       ...          ...              ...              ...
# 1216        0          1.0             0.58             0.08
# 1215        1          2.0             0.51             0.14
# 1228        0          2.0             0.60             0.07
# 1221        1          1.0             0.60             0.13
# 1229        0          0.0             0.50             0.08
#
#       team1_lag08_DREB  team1_lag08_FG_PCT  team1_lag08_FT_PCT  \
# 0                 0.65               0.422               0.750
# 1                 0.71               0.494               0.889
# 12                0.83               0.529               0.846
# 11                0.54               0.449               0.933
# 9                 0.79               0.474               0.854
# ...                ...                 ...                 ...
# 1216              0.74               0.514               0.798
# 1215              0.78               0.446               0.859
# 1228              0.74               0.465               0.757
# 1221              0.73               0.506               0.785
# 1229              0.58               0.428               0.750
#
#       team1_lag08_GP  team1_lag08_OREB  team1_lag08_PLUS_MINUS  \
# 0                1.0              0.21                   -0.13
# 1                1.0              0.25                    0.25
# 12               1.0              0.23                    0.33
# 11               1.0              0.21                   -0.33
# 9                1.0              0.19                   -0.23
# ...              ...               ...                     ...
# 1216             5.0              0.13                   -0.12
# 1215             4.0              0.25                    0.15
# 1228             5.0              0.20                   -0.07
# 1221             4.0              0.20                    0.40
# 1229             5.0              0.15                   -0.53
#
#       team1_lag08_PLUS_MINUS_RANK  team1_lag08_PTS  team1_lag08_PTS_RANK  \
# 0                            20.0             2.33                  19.0
# 1                             7.0             2.35                  17.0
# 12                            3.0             2.75                   2.0
# 11                           28.0             2.42                  15.0
# 9                            21.0             2.44                  13.0
# ...                           ...              ...                   ...
# 1216                         22.0             2.35                  20.0
# 1215                          9.0             2.40                  14.0
# 1228                         19.0             2.30                  24.0
# 1221                          1.0             2.61                   4.0
# 1229                         30.0             1.95                  30.0
#
#       team1_lag08_REB  team1_lag08_STL  team1_lag08_TOV  team1_lag08_W_PCT  \
# 0                0.85             0.27             0.25               0.00
# 1                0.96             0.19             0.42               1.00
# 12               1.06             0.06             0.29               1.00
# 11               0.75             0.17             0.13               0.00
# 9                0.98             0.08             0.35               0.00
# ...               ...              ...              ...                ...
# 1216             0.88             0.10             0.28               0.40
# 1215             1.03             0.12             0.29               0.75
# 1228             0.94             0.21             0.29               0.40
# 1221             0.94             0.17             0.28               1.00
# 1229             0.74             0.20             0.34               0.00
#
#       team1_lag08_W_PCT_RANK  team1_lag16_AST  team1_lag16_BLK  \
# 0                       16.0             0.29             0.10
# 1                        1.0             0.54             0.08
# 12                       1.0             0.50             0.13
# 11                      16.0             0.42             0.04
# 9                       16.0             0.48             0.06
# ...                      ...              ...              ...
# 1216                    20.0             0.58             0.10
# 1215                     6.0             0.53             0.14
# 1228                    20.0             0.57             0.07
# 1221                     1.0             0.53             0.12
# 1229                    27.0             0.52             0.08
#
#       team1_lag16_DREB  team1_lag16_FG_PCT  team1_lag16_FT_PCT  \
# 0                 0.65               0.422               0.750
# 1                 0.71               0.494               0.889
# 12                0.83               0.529               0.846
# 11                0.54               0.449               0.933
# 9                 0.79               0.474               0.854
# ...                ...                 ...                 ...
# 1216              0.74               0.499               0.793
# 1215              0.73               0.462               0.818
# 1228              0.70               0.481               0.760
# 1221              0.67               0.488               0.826
# 1229              0.57               0.440               0.748
#
#       team1_lag16_GP  team1_lag16_OREB  team1_lag16_PLUS_MINUS  \
# 0                1.0              0.21                   -0.13
# 1                1.0              0.25                    0.25
# 12               1.0              0.23                    0.33
# 11               1.0              0.21                   -0.33
# 9                1.0              0.19                   -0.23
# ...              ...               ...                     ...
# 1216            10.0              0.15                   -0.05
# 1215             8.0              0.22                    0.11
# 1228             8.0              0.18                    0.02
# 1221             7.0              0.18                    0.15
# 1229             9.0              0.24                   -0.40
#
#       team1_lag16_PLUS_MINUS_RANK  team1_lag16_PTS  team1_lag16_PTS_RANK  \
# 0                            20.0             2.33                  19.0
# 1                             7.0             2.35                  17.0
# 12                            3.0             2.75                   2.0
# 11                           28.0             2.42                  15.0
# 9                            21.0             2.44                  13.0
# ...                           ...              ...                   ...
# 1216                         20.0             2.31                  21.0
# 1215                         10.0             2.39                  15.0
# 1228                         14.0             2.38                  18.0
# 1221                          7.0             2.49                   6.0
# 1229                         30.0             2.08                  30.0
#
#       team1_lag16_REB  team1_lag16_STL  team1_lag16_TOV  team1_lag16_W_PCT  \
# 0                0.85             0.27             0.25              0.000
# 1                0.96             0.19             0.42              1.000
# 12               1.06             0.06             0.29              1.000
# 11               0.75             0.17             0.13              0.000
# 9                0.98             0.08             0.35              0.000
# ...               ...              ...              ...                ...
# 1216             0.89             0.11             0.28              0.500
# 1215             0.95             0.17             0.30              0.625
# 1228             0.89             0.18             0.28              0.625
# 1221             0.86             0.16             0.27              0.714
# 1229             0.81             0.21             0.35              0.000
#
#       team1_lag16_W_PCT_RANK  team1_lag180_AST  team1_lag180_BLK  \
# 0                       16.0              0.53              0.10
# 1                        1.0              0.58              0.09
# 12                       1.0              0.44              0.11
# 11                      16.0              0.55              0.09
# 9                       16.0              0.46              0.10
# ...                      ...               ...               ...
# 1216                    18.0              0.52              0.10
# 1215                     9.0              0.52              0.11
# 1228                     9.0              0.57              0.09
# 1221                     6.0              0.50              0.10
# 1229                    29.0              0.48              0.09
#
#       team1_lag180_DREB  team1_lag180_FG_PCT  team1_lag180_FT_PCT  \
# 0                  0.79                0.488                0.765
# 1                  0.73                0.474                0.785
# 12                 0.70                0.457                0.826
# 11                 0.71                0.486                0.819
# 9                  0.73                0.429                0.769
# ...                 ...                  ...                  ...
# 1216               0.71                0.472                0.786
# 1215               0.71                0.473                0.804
# 1228               0.74                0.486                0.798
# 1221               0.72                0.457                0.792
# 1229               0.68                0.443                0.760
#
#       team1_lag180_GP  team1_lag180_OREB  team1_lag180_PLUS_MINUS  \
# 0                58.0               0.21                     0.10
# 1                59.0               0.17                     0.04
# 12               58.0               0.23                     0.05
# 11               58.0               0.21                     0.11
# 9                58.0               0.21                    -0.21
# ...               ...                ...                      ...
# 1216             81.0               0.18                    -0.07
# 1215             81.0               0.21                     0.01
# 1228             81.0               0.20                     0.16
# 1221             81.0               0.19                    -0.01
# 1229             81.0               0.22                    -0.18
#
#       team1_lag180_PLUS_MINUS_RANK  team1_lag180_PTS  team1_lag180_PTS_RANK  \
# 0                              6.0              2.49                    1.0
# 1                             12.0              2.37                    9.0
# 12                            10.0              2.43                    4.0
# 11                             5.0              2.37                   12.0
# 9                             29.0              2.16                   30.0
# ...                            ...               ...                    ...
# 1216                          23.0              2.25                   22.0
# 1215                          15.0              2.34                    9.0
# 1228                           1.0              2.39                    4.0
# 1221                          20.0              2.24                   23.0
# 1229                          30.0              2.21                   26.0
#
#       team1_lag180_REB  team1_lag180_STL  team1_lag180_TOV  \
# 0                 1.00              0.16              0.28
# 1                 0.89              0.17              0.31
# 12                0.93              0.14              0.23
# 11                0.92              0.16              0.27
# 9                 0.94              0.14              0.26
# ...                ...               ...               ...
# 1216              0.89              0.13              0.27
# 1215              0.92              0.15              0.29
# 1228              0.94              0.18              0.27
# 1221              0.91              0.15              0.29
# 1229              0.89              0.17              0.30
#
#       team1_lag180_W_PCT  team1_lag180_W_PCT_RANK  team1_lag32_AST  \
# 0                  0.638                      6.0             0.29
# 1                  0.542                     14.0             0.54
# 12                 0.586                     11.0             0.50
# 11                 0.690                      3.0             0.42
# 9                  0.259                     29.0             0.48
# ...                  ...                      ...              ...
# 1216               0.432                     21.0             0.56
# 1215               0.531                     14.0             0.56
# 1228               0.790                      1.0             0.58
# 1221               0.506                     18.0             0.52
# 1229               0.333                     25.0             0.50
#
#       team1_lag32_BLK  team1_lag32_DREB  team1_lag32_FG_PCT  \
# 0                0.10              0.65               0.422
# 1                0.08              0.71               0.494
# 12               0.13              0.83               0.529
# 11               0.04              0.54               0.449
# 9                0.06              0.79               0.474
# ...               ...               ...                 ...
# 1216             0.10              0.71               0.485
# 1215             0.13              0.70               0.500
# 1228             0.09              0.73               0.496
# 1221             0.12              0.67               0.465
# 1229             0.09              0.59               0.442
#
#       team1_lag32_FT_PCT  team1_lag32_GP  team1_lag32_OREB  \
# 0                  0.750             1.0              0.21
# 1                  0.889             1.0              0.25
# 12                 0.846             1.0              0.23
# 11                 0.933             1.0              0.21
# 9                  0.854             1.0              0.19
# ...                  ...             ...               ...
# 1216               0.797            18.0              0.17
# 1215               0.807            16.0              0.22
# 1228               0.813            17.0              0.19
# 1221               0.833            15.0              0.18
# 1229               0.749            17.0              0.24
#
#       team1_lag32_PLUS_MINUS  team1_lag32_PLUS_MINUS_RANK  team1_lag32_PTS  \
# 0                      -0.13                         20.0             2.33
# 1                       0.25                          7.0             2.35
# 12                      0.33                          3.0             2.75
# 11                     -0.33                         28.0             2.42
# 9                      -0.23                         21.0             2.44
# ...                      ...                          ...              ...
# 1216                   -0.11                         23.0             2.30
# 1215                    0.16                          4.0             2.49
# 1228                    0.16                          5.0             2.46
# 1221                   -0.02                         19.0             2.32
# 1229                   -0.38                         30.0             2.16
#
#       team1_lag32_PTS_RANK  team1_lag32_REB  team1_lag32_STL  team1_lag32_TOV  \
# 0                     19.0             0.85             0.27             0.25
# 1                     17.0             0.96             0.19             0.42
# 12                     2.0             1.06             0.06             0.29
# 11                    15.0             0.75             0.17             0.13
# 9                     13.0             0.98             0.08             0.35
# ...                    ...              ...              ...              ...
# 1216                  20.0             0.87             0.13             0.26
# 1215                   4.0             0.92             0.17             0.30
# 1228                   8.0             0.93             0.17             0.27
# 1221                  19.0             0.85             0.15             0.25
# 1229                  29.0             0.84             0.19             0.33
#
#       team1_lag32_W_PCT  team1_lag32_W_PCT_RANK  team1_lag64_AST  \
# 0                 0.000                    16.0             0.29
# 1                 1.000                     1.0             0.54
# 12                1.000                     1.0             0.50
# 11                0.000                    16.0             0.42
# 9                 0.000                    16.0             0.48
# ...                 ...                     ...              ...
# 1216              0.333                    23.0             0.55
# 1215              0.688                     5.0             0.52
# 1228              0.765                     3.0             0.60
# 1221              0.467                    19.0             0.52
# 1229              0.118                    30.0             0.49
#
#       team1_lag64_BLK  team1_lag64_DREB  team1_lag64_FG_PCT  \
# 0                0.10              0.65               0.422
# 1                0.08              0.71               0.494
# 12               0.13              0.83               0.529
# 11               0.04              0.54               0.449
# 9                0.06              0.79               0.474
# ...               ...               ...                 ...
# 1216             0.10              0.67               0.484
# 1215             0.11              0.67               0.474
# 1228             0.10              0.73               0.497
# 1221             0.12              0.70               0.469
# 1229             0.08              0.63               0.433
#
#       team1_lag64_FT_PCT  team1_lag64_GP  team1_lag64_OREB  \
# 0                  0.750             1.0              0.21
# 1                  0.889             1.0              0.25
# 12                 0.846             1.0              0.23
# 11                 0.933             1.0              0.21
# 9                  0.854             1.0              0.19
# ...                  ...             ...               ...
# 1216               0.804            30.0              0.17
# 1215               0.780            30.0              0.23
# 1228               0.802            30.0              0.19
# 1221               0.800            27.0              0.19
# 1229               0.753            29.0              0.24
#
#       team1_lag64_PLUS_MINUS  team1_lag64_PLUS_MINUS_RANK  team1_lag64_PTS  \
# 0                      -0.13                         20.0             2.33
# 1                       0.25                          7.0             2.35
# 12                      0.33                          3.0             2.75
# 11                     -0.33                         28.0             2.42
# 9                      -0.23                         21.0             2.44
# ...                      ...                          ...              ...
# 1216                   -0.09                         21.0             2.29
# 1215                   -0.01                         18.0             2.37
# 1228                    0.16                          3.0             2.45
# 1221                   -0.01                         19.0             2.31
# 1229                   -0.35                         30.0             2.15
#
#       team1_lag64_PTS_RANK  team1_lag64_REB  team1_lag64_STL  team1_lag64_TOV  \
# 0                     19.0             0.85             0.27             0.25
# 1                     17.0             0.96             0.19             0.42
# 12                     2.0             1.06             0.06             0.29
# 11                    15.0             0.75             0.17             0.13
# 9                     13.0             0.98             0.08             0.35
# ...                    ...              ...              ...              ...
# 1216                  24.0             0.85             0.14             0.27
# 1215                  12.0             0.89             0.15             0.29
# 1228                   4.0             0.92             0.18             0.26
# 1221                  21.0             0.90             0.15             0.27
# 1229                  30.0             0.87             0.18             0.32
#
#       team1_lag64_W_PCT  team1_lag64_W_PCT_RANK  team2_L_cum  team2_W_cum  \
# 0                 0.000                    16.0          0.0          0.0
# 1                 1.000                     1.0          0.0          0.0
# 12                1.000                     1.0          0.0          0.0
# 11                0.000                    16.0          0.0          0.0
# 9                 0.000                    16.0          0.0          0.0
# ...                 ...                     ...          ...          ...
# 1216              0.367                    23.0          1.0          2.0
# 1215              0.467                    17.0          2.0          0.0
# 1228              0.767                     2.0          2.0          1.0
# 1221              0.519                    15.0          1.0          1.0
# 1229              0.207                    29.0          0.0          3.0
#
#       team2_lag08_AST  team2_lag08_BLK  team2_lag08_DREB  team2_lag08_FG_PCT  \
# 0                0.73             0.19              0.69               0.566
# 1                0.63             0.10              0.71               0.469
# 12               0.50             0.10              0.71               0.467
# 11               0.75             0.10              0.79               0.510
# 9                0.63             0.10              0.73               0.510
# ...               ...              ...               ...                 ...
# 1216             0.68             0.09              0.65               0.534
# 1215             0.60             0.16              0.62               0.497
# 1228             0.52             0.09              0.70               0.463
# 1221             0.50             0.12              0.73               0.453
# 1229             0.46             0.12              0.77               0.454
#
#       team2_lag08_FT_PCT  team2_lag08_GP  team2_lag08_OREB  \
# 0                  0.765             1.0              0.08
# 1                  0.600             1.0              0.17
# 12                 0.600             1.0              0.10
# 11                 1.000             1.0              0.21
# 9                  0.737             1.0              0.23
# ...                  ...             ...               ...
# 1216               0.785             4.0              0.17
# 1215               0.859             4.0              0.25
# 1228               0.788             4.0              0.13
# 1221               0.657             5.0              0.24
# 1229               0.715             4.0              0.28
#
#       team2_lag08_PLUS_MINUS  team2_lag08_PLUS_MINUS_RANK  team2_lag08_PTS  \
# 0                       0.29                          5.0             2.56
# 1                       0.25                          7.0             2.29
# 12                     -0.46                         29.0             2.06
# 11                      0.04                         15.0             2.56
# 9                      -0.04                         16.0             2.52
# ...                      ...                          ...              ...
# 1216                   -0.08                         20.0             2.55
# 1215                   -0.16                         24.0             2.51
# 1228                   -0.24                         27.0             2.18
# 1221                   -0.16                         25.0             2.16
# 1229                    0.16                          8.0             2.39
#
#       team2_lag08_PTS_RANK  team2_lag08_REB  team2_lag08_STL  team2_lag08_TOV  \
# 0                      6.0             0.77             0.19             0.25
# 1                     21.0             0.88             0.29             0.21
# 12                    26.0             0.81             0.21             0.27
# 11                     6.0             1.00             0.15             0.17
# 9                      8.0             0.96             0.10             0.21
# ...                    ...              ...              ...              ...
# 1216                   7.0             0.82             0.20             0.29
# 1215                   8.0             0.87             0.16             0.35
# 1228                  27.0             0.82             0.14             0.28
# 1221                  28.0             0.96             0.14             0.32
# 1229                  16.0             1.05             0.16             0.27
#
#       team2_lag08_W_PCT  team2_lag08_W_PCT_RANK  team2_lag16_AST  \
# 0                  1.00                     1.0             0.73
# 1                  1.00                     1.0             0.63
# 12                 0.00                    16.0             0.50
# 11                 1.00                     1.0             0.75
# 9                  0.00                    16.0             0.63
# ...                 ...                     ...              ...
# 1216               0.50                    13.0             0.66
# 1215               0.00                    27.0             0.57
# 1228               0.25                    23.0             0.49
# 1221               0.40                    20.0             0.54
# 1229               0.50                    13.0             0.48
#
#       team2_lag16_BLK  team2_lag16_DREB  team2_lag16_FG_PCT  \
# 0                0.19              0.69               0.566
# 1                0.10              0.71               0.469
# 12               0.10              0.71               0.467
# 11               0.10              0.79               0.510
# 9                0.10              0.73               0.510
# ...               ...               ...                 ...
# 1216             0.08              0.66               0.505
# 1215             0.13              0.54               0.475
# 1228             0.10              0.68               0.457
# 1221             0.10              0.71               0.467
# 1229             0.09              0.69               0.473
#
#       team2_lag16_FT_PCT  team2_lag16_GP  team2_lag16_OREB  \
# 0                  0.765             1.0              0.08
# 1                  0.600             1.0              0.17
# 12                 0.600             1.0              0.10
# 11                 1.000             1.0              0.21
# 9                  0.737             1.0              0.23
# ...                  ...             ...               ...
# 1216               0.777             8.0              0.21
# 1215               0.814             8.0              0.24
# 1228               0.775             7.0              0.18
# 1221               0.699             8.0              0.21
# 1229               0.681             8.0              0.23
#
#       team2_lag16_PLUS_MINUS  team2_lag16_PLUS_MINUS_RANK  team2_lag16_PTS  \
# 0                       0.29                          5.0             2.56
# 1                       0.25                          7.0             2.29
# 12                     -0.46                         29.0             2.06
# 11                      0.04                         15.0             2.56
# 9                      -0.04                         16.0             2.52
# ...                      ...                          ...              ...
# 1216                    0.02                         16.0             2.47
# 1215                   -0.30                         29.0             2.39
# 1228                   -0.18                         27.0             2.21
# 1221                   -0.15                         24.0             2.25
# 1229                    0.05                         13.0             2.33
#
#       team2_lag16_PTS_RANK  team2_lag16_REB  team2_lag16_STL  team2_lag16_TOV  \
# 0                      6.0             0.77             0.19             0.25
# 1                     21.0             0.88             0.29             0.21
# 12                    26.0             0.81             0.21             0.27
# 11                     6.0             1.00             0.15             0.17
# 9                      8.0             0.96             0.10             0.21
# ...                    ...              ...              ...              ...
# 1216                   8.0             0.87             0.18             0.27
# 1215                  16.0             0.78             0.16             0.30
# 1228                  28.0             0.86             0.13             0.27
# 1221                  25.0             0.92             0.14             0.34
# 1229                  20.0             0.93             0.14             0.24
#
#       team2_lag16_W_PCT  team2_lag16_W_PCT_RANK  team2_lag180_AST  \
# 0                 1.000                     1.0              0.56
# 1                 1.000                     1.0              0.50
# 12                0.000                    16.0              0.53
# 11                1.000                     1.0              0.56
# 9                 0.000                    16.0              0.50
# ...                 ...                     ...               ...
# 1216              0.625                     9.0              0.58
# 1215              0.000                    29.0              0.52
# 1228              0.429                    20.0              0.49
# 1221              0.375                    21.0              0.46
# 1229              0.375                    21.0              0.47
#
#       team2_lag180_BLK  team2_lag180_DREB  team2_lag180_FG_PCT  \
# 0                 0.11               0.72                0.494
# 1                 0.10               0.69                0.468
# 12                0.10               0.67                0.482
# 11                0.09               0.70                0.495
# 9                 0.10               0.70                0.466
# ...                ...                ...                  ...
# 1216              0.10               0.70                0.467
# 1215              0.12               0.68                0.463
# 1228              0.09               0.69                0.459
# 1221              0.10               0.73                0.430
# 1229              0.10               0.74                0.471
#
#       team2_lag180_FT_PCT  team2_lag180_GP  team2_lag180_OREB  \
# 0                   0.804             57.0               0.19
# 1                   0.735             57.0               0.19
# 12                  0.750             58.0               0.19
# 11                  0.840             60.0               0.18
# 9                   0.792             58.0               0.19
# ...                   ...              ...                ...
# 1216                0.741             81.0               0.22
# 1215                0.769             81.0               0.23
# 1228                0.769             81.0               0.20
# 1221                0.757             81.0               0.22
# 1229                0.768             81.0               0.22
#
#       team2_lag180_PLUS_MINUS  team2_lag180_PLUS_MINUS_RANK  team2_lag180_PTS  \
# 0                        0.09                           7.0              2.45
# 1                        0.02                          15.0              2.22
# 12                      -0.05                          23.0              2.37
# 11                       0.13                           2.0              2.39
# 9                       -0.05                          24.0              2.29
# ...                       ...                           ...               ...
# 1216                     0.01                          17.0              2.38
# 1215                    -0.07                          24.0              2.29
# 1228                    -0.12                          25.0              2.28
# 1221                    -0.16                          26.0              2.15
# 1229                     0.12                           4.0              2.36
#
#       team2_lag180_PTS_RANK  team2_lag180_REB  team2_lag180_STL  \
# 0                       2.0              0.91              0.14
# 1                      26.0              0.89              0.17
# 12                     13.0              0.86              0.16
# 11                      7.0              0.89              0.15
# 9                      20.0              0.89              0.14
# ...                     ...               ...               ...
# 1216                    5.0              0.92              0.18
# 1215                   13.0              0.91              0.14
# 1228                   16.0              0.89              0.15
# 1221                   30.0              0.95              0.16
# 1229                    7.0              0.96              0.15
#
#       team2_lag180_TOV  team2_lag180_W_PCT  team2_lag180_W_PCT_RANK  \
# 0                 0.27               0.684                      5.0
# 1                 0.31               0.544                     13.0
# 12                0.28               0.448                     19.0
# 11                0.26               0.733                      1.0
# 9                 0.24               0.431                     22.0
# ...                ...                 ...                      ...
# 1216              0.27               0.519                     16.0
# 1215              0.30               0.309                     26.0
# 1228              0.29               0.358                     24.0
# 1221              0.29               0.296                     27.0
# 1229              0.29               0.593                      9.0
#
#       team2_lag32_AST  team2_lag32_BLK  team2_lag32_DREB  team2_lag32_FG_PCT  \
# 0                0.73             0.19              0.69               0.566
# 1                0.63             0.10              0.71               0.469
# 12               0.50             0.10              0.71               0.467
# 11               0.75             0.10              0.79               0.510
# 9                0.63             0.10              0.73               0.510
# ...               ...              ...               ...                 ...
# 1216             0.65             0.10              0.66               0.504
# 1215             0.59             0.12              0.59               0.483
# 1228             0.51             0.09              0.66               0.463
# 1221             0.52             0.09              0.71               0.462
# 1229             0.46             0.10              0.72               0.467
#
#       team2_lag32_FT_PCT  team2_lag32_GP  team2_lag32_OREB  \
# 0                  0.765             1.0              0.08
# 1                  0.600             1.0              0.17
# 12                 0.600             1.0              0.10
# 11                 1.000             1.0              0.21
# 9                  0.737             1.0              0.23
# ...                  ...             ...               ...
# 1216               0.773            16.0              0.21
# 1215               0.812            15.0              0.25
# 1228               0.791            14.0              0.16
# 1221               0.731            17.0              0.21
# 1229               0.733            17.0              0.24
#
#       team2_lag32_PLUS_MINUS  team2_lag32_PLUS_MINUS_RANK  team2_lag32_PTS  \
# 0                       0.29                          5.0             2.56
# 1                       0.25                          7.0             2.29
# 12                     -0.46                         29.0             2.06
# 11                      0.04                         15.0             2.56
# 9                      -0.04                         16.0             2.52
# ...                      ...                          ...              ...
# 1216                    0.05                         13.0             2.48
# 1215                   -0.16                         25.0             2.43
# 1228                   -0.16                         26.0             2.27
# 1221                   -0.19                         28.0             2.29
# 1229                    0.10                          7.0             2.36
#
#       team2_lag32_PTS_RANK  team2_lag32_REB  team2_lag32_STL  team2_lag32_TOV  \
# 0                      6.0             0.77             0.19             0.25
# 1                     21.0             0.88             0.29             0.21
# 12                    26.0             0.81             0.21             0.27
# 11                     6.0             1.00             0.15             0.17
# 9                      8.0             0.96             0.10             0.21
# ...                    ...              ...              ...              ...
# 1216                   5.0             0.87             0.18             0.26
# 1215                   9.0             0.84             0.16             0.31
# 1228                  27.0             0.83             0.15             0.28
# 1221                  22.0             0.92             0.14             0.32
# 1229                  17.0             0.96             0.15             0.26
#
#       team2_lag32_W_PCT  team2_lag32_W_PCT_RANK  team2_lag64_AST  \
# 0                 1.000                     1.0             0.73
# 1                 1.000                     1.0             0.63
# 12                0.000                    16.0             0.50
# 11                1.000                     1.0             0.75
# 9                 0.000                    16.0             0.63
# ...                 ...                     ...              ...
# 1216              0.625                     9.0             0.61
# 1215              0.200                    29.0             0.56
# 1228              0.357                    21.0             0.51
# 1221              0.235                    27.0             0.50
# 1229              0.471                    18.0             0.48
#
#       team2_lag64_BLK  team2_lag64_DREB  team2_lag64_FG_PCT  \
# 0                0.19              0.69               0.566
# 1                0.10              0.71               0.469
# 12               0.10              0.71               0.467
# 11               0.10              0.79               0.510
# 9                0.10              0.73               0.510
# ...               ...               ...                 ...
# 1216             0.09              0.69               0.478
# 1215             0.11              0.63               0.475
# 1228             0.08              0.69               0.472
# 1221             0.10              0.72               0.451
# 1229             0.10              0.73               0.470
#
#       team2_lag64_FT_PCT  team2_lag64_GP  team2_lag64_OREB  \
# 0                  0.765             1.0              0.08
# 1                  0.600             1.0              0.17
# 12                 0.600             1.0              0.10
# 11                 1.000             1.0              0.21
# 9                  0.737             1.0              0.23
# ...                  ...             ...               ...
# 1216               0.749            29.0              0.23
# 1215               0.778            28.0              0.25
# 1228               0.791            27.0              0.17
# 1221               0.742            31.0              0.21
# 1229               0.751            29.0              0.24
#
#       team2_lag64_PLUS_MINUS  team2_lag64_PLUS_MINUS_RANK  team2_lag64_PTS  \
# 0                       0.29                          5.0             2.56
# 1                       0.25                          7.0             2.29
# 12                     -0.46                         29.0             2.06
# 11                      0.04                         15.0             2.56
# 9                      -0.04                         16.0             2.52
# ...                      ...                          ...              ...
# 1216                    0.02                         15.0             2.40
# 1215                   -0.13                         26.0             2.39
# 1228                   -0.13                         24.0             2.31
# 1221                   -0.19                         29.0             2.24
# 1229                    0.12                          5.0             2.36
#
#       team2_lag64_PTS_RANK  team2_lag64_REB  team2_lag64_STL  team2_lag64_TOV  \
# 0                      6.0             0.77             0.19             0.25
# 1                     21.0             0.88             0.29             0.21
# 12                    26.0             0.81             0.21             0.27
# 11                     6.0             1.00             0.15             0.17
# 9                      8.0             0.96             0.10             0.21
# ...                    ...              ...              ...              ...
# 1216                  10.0             0.92             0.17             0.28
# 1215                  11.0             0.88             0.15             0.31
# 1228                  18.0             0.86             0.14             0.29
# 1221                  28.0             0.93             0.16             0.31
# 1229                  13.0             0.97             0.15             0.28
#
#       team2_lag64_W_PCT  team2_lag64_W_PCT_RANK  SEASON
# 0                 1.000                     1.0      31
# 1                 1.000                     1.0      31
# 12                0.000                    16.0      31
# 11                1.000                     1.0      31
# 9                 0.000                    16.0      31
# ...                 ...                     ...     ...
# 1216              0.483                    16.0      31
# 1215              0.214                    28.0      31
# 1228              0.370                    22.0      31
# 1221              0.258                    26.0      31
# 1229              0.586                    11.0      31
#
# [1230 rows x 170 columns]

# %%
df_train_arr_v2[0]
# Out:
#     DATE_WITHIN_SEASON  IS_REGULAR  team1_IS_HOME  team1_L_cum  \
# 33                 0.0         0.0            0.0          0.0
# 28                 0.0         0.0            1.0          0.0
# 18                 0.0         0.0            1.0          0.0
# 38                 0.0         0.0            1.0          0.0
# 24                 1.0         0.0            0.0          0.0
# ..                 ...         ...            ...          ...
# 81                50.0         0.0            1.0          0.0
# 82                52.0         0.0            0.0          0.0
# 83                54.0         0.0            0.0          1.0
# 84                57.0         0.0            0.0          1.0
# 85                59.0         0.0            1.0          2.0
#
#     team1_PStat_lag08_AST  team1_PStat_lag08_AST_RANK  team1_PStat_lag08_BLK  \
# 33               0.091111                  188.111111               0.016667
# 28               0.090000                  192.900000               0.022000
# 18               0.066667                  193.222222               0.025556
# 38               0.096667                  165.666667               0.013333
# 24               0.097500                  150.750000               0.041250
# ..                    ...                         ...                    ...
# 81               0.068889                   58.074074               0.025185
# 82               0.083333                   64.566667               0.020000
# 83               0.084545                   54.227273               0.023182
# 84               0.080417                   49.508333               0.019750
# 85               0.074667                   54.160606               0.019455
#
#     team1_PStat_lag08_DREB  team1_PStat_lag08_DREB_RANK  \
# 33                0.160000                   146.000000
# 28                0.107000                   214.100000
# 18                0.145556                   153.222222
# 38                0.125000                   187.333333
# 24                0.156250                   143.750000
# ..                     ...                          ...
# 81                0.127037                    60.888889
# 82                0.121667                    68.100000
# 83                0.124091                    56.772727
# 84                0.141917                    48.308333
# 85                0.137667                    40.531818
#
#     team1_PStat_lag08_FG3M  team1_PStat_lag08_FG3M_RANK  \
# 33                0.022222                   142.666667
# 28                0.021000                   146.800000
# 18                0.015556                   157.111111
# 38                0.034167                   134.250000
# 24                0.027500                   136.750000
# ..                     ...                          ...
# 81                0.022593                    33.444444
# 82                0.037000                    31.500000
# 83                0.030909                    32.977273
# 84                0.033000                    28.633333
# 85                0.028455                    32.846970
#
#     team1_PStat_lag08_FG3_PCT  team1_PStat_lag08_FG3_PCT_RANK  \
# 33                   0.174778                      141.666667
# 28                   0.229000                      139.400000
# 18                   0.145778                      155.888889
# 38                   0.163917                      151.416667
# 24                   0.292750                      102.375000
# ..                        ...                             ...
# 81                   0.178185                       31.629630
# 82                   0.242967                       30.866667
# 83                   0.209273                       32.159091
# 84                   0.220358                       27.616667
# 85                   0.168927                       33.210606
#
#     team1_PStat_lag08_FGM_RANK  team1_PStat_lag08_FG_PCT  \
# 33                  172.000000                  0.481444
# 28                  167.900000                  0.502000
# 18                  188.888889                  0.423778
# 38                  182.583333                  0.411917
# 24                  169.125000                  0.505000
# ..                         ...                       ...
# 81                   59.148148                  0.411481
# 82                   56.066667                  0.479467
# 83                   52.295455                  0.457659
# 84                   44.066667                  0.402033
# 85                   48.533333                  0.462267
#
#     team1_PStat_lag08_FG_PCT_RANK  team1_PStat_lag08_FTM  \
# 33                     148.222222               0.083333
# 28                     150.100000               0.068000
# 18                     194.111111               0.081111
# 38                     184.583333               0.060833
# 24                     123.125000               0.105000
# ..                            ...                    ...
# 81                      53.703704               0.081111
# 82                      59.333333               0.089000
# 83                      47.840909               0.100455
# 84                      44.925000               0.090583
# 85                      50.628788               0.092576
#
#     team1_PStat_lag08_FT_PCT  team1_PStat_lag08_FT_PCT_RANK  \
# 33                  0.735889                     133.888889
# 28                  0.574900                     154.000000
# 18                  0.684000                     154.666667
# 38                  0.600417                     157.250000
# 24                  0.661750                     163.750000
# ..                       ...                            ...
# 81                  0.531852                      49.222222
# 82                  0.479733                      58.233333
# 83                  0.558841                      38.318182
# 84                  0.518133                      37.375000
# 85                  0.586585                      38.980303
#
#     team1_PStat_lag08_GP  team1_PStat_lag08_NBA_FANTASY_PTS  \
# 33              2.888889                           0.843333
# 28              3.600000                           0.942000
# 18              3.666667                           0.840000
# 38              3.583333                           0.828333
# 24              3.000000                           0.975000
# ..                   ...                                ...
# 81              1.666667                           0.823704
# 82              1.600000                           0.945000
# 83              2.227273                           0.912045
# 84              2.266667                           0.861667
# 85              2.860606                           0.851727
#
#     team1_PStat_lag08_NBA_FANTASY_PTS_RANK  team1_PStat_lag08_OREB  \
# 33                              185.555556                0.040000
# 28                              166.500000                0.048000
# 18                              174.222222                0.064444
# 38                              179.833333                0.055000
# 24                              127.250000                0.027500
# ..                                     ...                     ...
# 81                               57.185185                0.054074
# 82                               50.866667                0.045333
# 83                               45.409091                0.043409
# 84                               39.425000                0.038750
# 85                               50.334848                0.047591
#
#     team1_PStat_lag08_OREB_RANK  team1_PStat_lag08_PLUS_MINUS  \
# 33                   198.000000                      0.023333
# 28                   192.600000                     -0.112000
# 18                   156.111111                      0.021111
# 38                   178.000000                      0.001667
# 24                   209.000000                      0.070000
# ..                          ...                           ...
# 81                    52.925926                      0.141852
# 82                    61.366667                      0.244667
# 83                    55.159091                      0.163409
# 84                    47.975000                      0.342250
# 85                    45.045455                      0.159091
#
#     team1_PStat_lag08_PLUS_MINUS_RANK  team1_PStat_lag08_PTS  \
# 33                         164.111111               0.428889
# 28                         192.400000               0.405000
# 18                         168.444444               0.381111
# 38                         168.166667               0.380000
# 24                         147.375000               0.465000
# ..                                ...                    ...
# 81                          46.814815               0.374444
# 82                          43.066667               0.443667
# 83                          39.386364               0.423636
# 84                          34.183333               0.396833
# 85                          30.325758               0.413576
#
#     team1_PStat_lag08_PTS_RANK  team1_PStat_lag08_STL  \
# 33                  172.222222               0.014444
# 28                  168.800000               0.063000
# 18                  186.777778               0.023333
# 38                  179.166667               0.028333
# 24                  158.500000               0.028750
# ..                         ...                    ...
# 81                   59.481481               0.033704
# 82                   57.066667               0.057000
# 83                   46.500000               0.045682
# 84                   40.683333               0.038333
# 85                   44.890909               0.035803
#
#     team1_PStat_lag08_STL_RANK  team1_PStat_lag08_TOV  \
# 33                  202.000000               0.063333
# 28                  148.100000               0.043000
# 18                  170.888889               0.050000
# 38                  163.083333               0.038333
# 24                  141.625000               0.066250
# ..                         ...                    ...
# 81                   36.888889               0.050000
# 82                   32.100000               0.053667
# 83                   33.363636               0.048182
# 84                   29.333333               0.045500
# 85                   33.972727               0.062273
#
#     team1_PStat_lag08_TOV_RANK  team1_PStat_lag08_W_PCT  \
# 33                  148.888889                 0.648444
# 28                  202.000000                 0.300000
# 18                  184.666667                 0.518556
# 38                  212.666667                 0.513917
# 24                  120.875000                 0.667000
# ..                         ...                      ...
# 81                   48.259259                 1.000000
# 82                   44.633333                 1.000000
# 83                   46.454545                 0.750205
# 84                   42.333333                 0.766867
# 85                   31.181818                 0.646970
#
#     team1_PStat_lag08_W_PCT_RANK  team1_PStat_lag16_AST  \
# 33                    112.444444               0.090000
# 28                    233.700000               0.085000
# 18                    149.888889               0.078889
# 38                    144.666667               0.085833
# 24                    100.000000               0.101250
# ..                           ...                    ...
# 81                      1.000000               0.068889
# 82                      1.000000               0.070667
# 83                      1.863636               0.074545
# 84                      2.266667               0.072917
# 85                      3.639394               0.073985
#
#     team1_PStat_lag16_AST_RANK  team1_PStat_lag16_BLK  team1_PStat_lag16_DREB  \
# 33                  184.666667               0.030000                0.160000
# 28                  213.500000               0.018000                0.118000
# 18                  191.111111               0.027778                0.134444
# 38                  182.666667               0.016667                0.139167
# 24                  147.250000               0.030000                0.147500
# ..                         ...                    ...                     ...
# 81                   64.888889               0.024444                0.123333
# 82                   73.500000               0.020667                0.119667
# 83                   62.636364               0.021136                0.122273
# 84                   56.150000               0.018250                0.144167
# 85                   54.309091               0.019455                0.140530
#
#     team1_PStat_lag16_DREB_RANK  team1_PStat_lag16_FG3M  \
# 33                   154.555556                0.026667
# 28                   211.900000                0.024000
# 18                   174.555556                0.015556
# 38                   170.333333                0.035000
# 24                   166.875000                0.033750
# ..                          ...                     ...
# 81                    67.555556                0.023333
# 82                    74.566667                0.034333
# 83                    62.909091                0.028409
# 84                    53.066667                0.031500
# 85                    39.998485                0.027727
#
#     team1_PStat_lag16_FG3M_RANK  team1_PStat_lag16_FG3_PCT  \
# 33                   154.000000                   0.273111
# 28                   155.800000                   0.190600
# 18                   175.777778                   0.198556
# 38                   145.333333                   0.191333
# 24                   141.000000                   0.297875
# ..                          ...                        ...
# 81                    40.259259                   0.203519
# 82                    37.433333                   0.263967
# 83                    38.931818                   0.232795
# 84                    32.133333                   0.214208
# 85                    32.774242                   0.167400
#
#     team1_PStat_lag16_FG3_PCT_RANK  team1_PStat_lag16_FGM_RANK  \
# 33                      127.444444                  170.777778
# 28                      160.200000                  170.800000
# 18                      158.555556                  194.444444
# 38                      160.416667                  193.250000
# 24                      138.500000                  160.750000
# ..                             ...                         ...
# 81                       38.518519                   65.592593
# 82                       35.666667                   62.066667
# 83                       36.727273                   59.250000
# 84                       31.775000                   48.583333
# 85                       33.283333                   48.674242
#
#     team1_PStat_lag16_FG_PCT  team1_PStat_lag16_FG_PCT_RANK  \
# 33                  0.495889                     130.555556
# 28                  0.519700                     144.900000
# 18                  0.436556                     191.000000
# 38                  0.434000                     174.333333
# 24                  0.481750                     134.250000
# ..                       ...                            ...
# 81                  0.426815                      60.962963
# 82                  0.448667                      66.133333
# 83                  0.433795                      55.272727
# 84                  0.403158                      52.266667
# 85                  0.454267                      50.987879
#
#     team1_PStat_lag16_FTM  team1_PStat_lag16_FT_PCT  \
# 33               0.077778                  0.783333
# 28               0.069000                  0.715600
# 18               0.078889                  0.673444
# 38               0.053333                  0.595167
# 24               0.098750                  0.742125
# ..                    ...                       ...
# 81               0.084074                  0.613481
# 82               0.089667                  0.533333
# 83               0.103864                  0.586455
# 84               0.090583                  0.548508
# 85               0.094030                  0.603908
#
#     team1_PStat_lag16_FT_PCT_RANK  team1_PStat_lag16_GP  \
# 33                     139.222222              6.666667
# 28                     181.200000              8.500000
# 18                     195.333333              7.555556
# 38                     189.750000              7.416667
# 24                     175.625000              6.875000
# ..                            ...                   ...
# 81                      53.814815              4.111111
# 82                      64.500000              3.866667
# 83                      45.363636              4.136364
# 84                      43.925000              3.533333
# 85                      38.877273              3.437879
#
#     team1_PStat_lag16_NBA_FANTASY_PTS  team1_PStat_lag16_NBA_FANTASY_PTS_RANK  \
# 33                           0.904444                              165.888889
# 28                           0.880000                              169.400000
# 18                           0.871111                              177.222222
# 38                           0.809167                              194.000000
# 24                           0.966250                              123.875000
# ..                                ...                                     ...
# 81                           0.804444                               65.185185
# 82                           0.900333                               58.600000
# 83                           0.858409                               53.068182
# 84                           0.858667                               44.800000
# 85                           0.844409                               50.272727
#
#     team1_PStat_lag16_OREB  team1_PStat_lag16_OREB_RANK  \
# 33                0.044444                   200.666667
# 28                0.046000                   191.300000
# 18                0.062222                   151.555556
# 38                0.052500                   199.000000
# 24                0.036250                   216.750000
# ..                     ...                          ...
# 81                0.059259                    56.703704
# 82                0.047333                    66.166667
# 83                0.043409                    60.750000
# 84                0.041000                    52.550000
# 85                0.047636                    45.118182
#
#     team1_PStat_lag16_PLUS_MINUS  team1_PStat_lag16_PLUS_MINUS_RANK  \
# 33                      0.170000                         100.666667
# 28                      0.166000                         111.600000
# 18                      0.021111                         180.333333
# 38                      0.240833                          96.333333
# 24                      0.111250                         129.500000
# ..                           ...                                ...
# 81                      0.017407                          57.629630
# 82                      0.150000                          49.400000
# 83                      0.103636                          48.181818
# 84                      0.378250                          35.975000
# 85                      0.199136                          29.312121
#
#     team1_PStat_lag16_PTS  team1_PStat_lag16_PTS_RANK  team1_PStat_lag16_STL  \
# 33               0.433333                  171.000000               0.021111
# 28               0.405000                  170.100000               0.048000
# 18               0.387778                  194.111111               0.026667
# 38               0.369167                  191.750000               0.024167
# 24               0.475000                  152.750000               0.032500
# ..                    ...                         ...                    ...
# 81               0.372222                   65.481481               0.030741
# 82               0.426333                   62.866667               0.053667
# 83               0.407727                   53.681818               0.042273
# 84               0.401333                   45.350000               0.038333
# 85               0.408848                   45.253030               0.035121
#
#     team1_PStat_lag16_STL_RANK  team1_PStat_lag16_TOV  \
# 33                  236.555556               0.056667
# 28                  126.600000               0.042000
# 18                  185.666667               0.047778
# 38                  209.083333               0.040833
# 24                  163.250000               0.062500
# ..                         ...                    ...
# 81                   44.222222               0.053704
# 82                   37.900000               0.058333
# 83                   39.022727               0.052273
# 84                   33.308333               0.047000
# 85                   34.553030               0.060818
#
#     team1_PStat_lag16_TOV_RANK  team1_PStat_lag16_W_PCT  \
# 33                  184.222222                 0.716778
# 28                  217.200000                 0.574800
# 18                  204.111111                 0.500000
# 38                  220.916667                 0.767000
# 24                  140.125000                 0.583000
# ..                         ...                      ...
# 81                   50.629630                 0.775481
# 82                   49.700000                 0.894267
# 83                   50.590909                 0.768364
# 84                   47.866667                 0.857800
# 85                   30.810606                 0.703538
#
#     team1_PStat_lag16_W_PCT_RANK  team1_PStat_lag180_AST  \
# 33                     81.111111                0.097778
# 28                    155.900000                0.080000
# 18                    180.777778                0.083333
# 38                     53.000000                0.071667
# 24                    141.375000                0.098750
# ..                           ...                     ...
# 81                      4.925926                0.083704
# 82                      3.333333                0.085333
# 83                      3.795455                0.083864
# 84                      2.266667                0.084250
# 85                      4.124242                0.071742
#
#     team1_PStat_lag180_AST_RANK  team1_PStat_lag180_BLK  \
# 33                   194.555556                0.030000
# 28                   255.600000                0.017000
# 18                   206.666667                0.024444
# 38                   237.583333                0.018333
# 24                   162.750000                0.025000
# ..                          ...                     ...
# 81                   114.037037                0.020000
# 82                   114.100000                0.019000
# 83                   109.818182                0.017273
# 84                   100.933333                0.014000
# 85                   132.322727                0.018652
#
#     team1_PStat_lag180_DREB  team1_PStat_lag180_DREB_RANK  \
# 33                 0.137778                    204.222222
# 28                 0.123000                    232.000000
# 18                 0.137778                    187.444444
# 38                 0.130833                    210.666667
# 24                 0.135000                    220.375000
# ..                      ...                           ...
# 81                 0.124074                    121.518519
# 82                 0.121667                    137.533333
# 83                 0.118409                    139.590909
# 84                 0.111250                    136.600000
# 85                 0.118909                    126.503030
#
#     team1_PStat_lag180_FG3M  team1_PStat_lag180_FG3M_RANK  \
# 33                 0.028889                    176.888889
# 28                 0.025000                    202.000000
# 18                 0.024444                    201.444444
# 38                 0.033333                    185.000000
# 24                 0.032500                    178.125000
# ..                      ...                           ...
# 81                 0.019630                    121.444444
# 82                 0.026667                    110.933333
# 83                 0.024318                    113.681818
# 84                 0.025083                    103.408333
# 85                 0.021576                    118.416667
#
#     team1_PStat_lag180_FG3_PCT  team1_PStat_lag180_FG3_PCT_RANK  \
# 33                    0.342889                       137.222222
# 28                    0.245000                       178.600000
# 18                    0.203556                       200.888889
# 38                    0.182250                       215.250000
# 24                    0.329125                       155.750000
# ..                         ...                              ...
# 81                    0.200778                       119.592593
# 82                    0.220633                       117.100000
# 83                    0.229614                       112.181818
# 84                    0.236617                       103.966667
# 85                    0.190717                       118.033333
#
#     team1_PStat_lag180_FGM_RANK  team1_PStat_lag180_FG_PCT  \
# 33                   150.000000                   0.495000
# 28                   195.900000                   0.475900
# 18                   209.222222                   0.441556
# 38                   185.333333                   0.487917
# 24                   164.250000                   0.475250
# ..                          ...                        ...
# 81                   125.185185                   0.460185
# 82                   132.133333                   0.459633
# 83                   135.045455                   0.446091
# 84                   122.425000                   0.431842
# 85                   141.289394                   0.461642
#
#     team1_PStat_lag180_FG_PCT_RANK  team1_PStat_lag180_FTM  \
# 33                      126.222222                0.075556
# 28                      166.700000                0.063000
# 18                      226.333333                0.074444
# 38                      154.833333                0.050000
# 24                      139.875000                0.090000
# ..                             ...                     ...
# 81                      109.555556                0.084444
# 82                      128.400000                0.080000
# 83                      127.090909                0.081818
# 84                      126.458333                0.079750
# 85                      104.772727                0.078242
#
#     team1_PStat_lag180_FT_PCT  team1_PStat_lag180_FT_PCT_RANK  \
# 33                   0.769333                      154.222222
# 28                   0.732400                      215.300000
# 18                   0.716000                      224.111111
# 38                   0.646000                      264.166667
# 24                   0.729125                      230.500000
# ..                        ...                             ...
# 81                   0.785074                      105.333333
# 82                   0.800633                       97.266667
# 83                   0.799864                       93.227273
# 84                   0.776483                       92.941667
# 85                   0.739403                      122.907576
#
#     team1_PStat_lag180_GP  team1_PStat_lag180_NBA_FANTASY_PTS  \
# 33              72.444444                            0.904444
# 28              71.600000                            0.826000
# 18              68.555556                            0.862222
# 38              53.583333                            0.808333
# 24              76.250000                            0.965000
# ..                    ...                                 ...
# 81              30.074074                            0.808889
# 82              33.666667                            0.805667
# 83              32.431818                            0.789091
# 84              29.791667                            0.771417
# 85              31.354545                            0.764121
#
#     team1_PStat_lag180_NBA_FANTASY_PTS_RANK  team1_PStat_lag180_OREB  \
# 33                               156.111111                 0.041111
# 28                               216.600000                 0.053000
# 18                               194.444444                 0.062222
# 38                               207.416667                 0.058333
# 24                               100.625000                 0.045000
# ..                                      ...                      ...
# 81                               112.666667                 0.052593
# 82                               125.433333                 0.048333
# 83                               128.727273                 0.046364
# 84                               124.283333                 0.041750
# 85                               136.719697                 0.052182
#
#     team1_PStat_lag180_OREB_RANK  team1_PStat_lag180_PLUS_MINUS  \
# 33                    251.333333                       0.082222
# 28                    204.800000                       0.081000
# 18                    182.777778                       0.005556
# 38                    218.000000                       0.114167
# 24                    226.625000                       0.093750
# ..                           ...                            ...
# 81                    126.962963                       0.100370
# 82                    153.033333                       0.113333
# 83                    144.477273                       0.104318
# 84                    142.516667                       0.082083
# 85                    114.518182                       0.083045
#
#     team1_PStat_lag180_PLUS_MINUS_RANK  team1_PStat_lag180_PTS  \
# 33                          113.111111                0.438889
# 28                          110.500000                0.386000
# 18                          189.888889                0.394444
# 38                          107.583333                0.380000
# 24                           99.375000                0.458750
# ..                                 ...                     ...
# 81                           67.444444                0.380741
# 82                           63.200000                0.384667
# 83                           61.318182                0.372727
# 84                           70.908333                0.376417
# 85                           71.156061                0.361106
#
#     team1_PStat_lag180_PTS_RANK  team1_PStat_lag180_STL  \
# 33                   165.222222                0.024444
# 28                   201.600000                0.036000
# 18                   212.888889                0.030000
# 38                   201.166667                0.025833
# 24                   168.625000                0.037500
# ..                          ...                     ...
# 81                   119.888889                0.027037
# 82                   125.533333                0.029000
# 83                   125.409091                0.030455
# 84                   114.258333                0.029250
# 85                   132.986364                0.027576
#
#     team1_PStat_lag180_STL_RANK  team1_PStat_lag180_TOV  \
# 33                   270.000000                0.063333
# 28                   188.000000                0.050000
# 18                   225.555556                0.052222
# 38                   242.916667                0.041667
# 24                   107.000000                0.058750
# ..                          ...                     ...
# 81                   123.777778                0.050741
# 82                   122.133333                0.050667
# 83                   102.954545                0.051136
# 84                    98.041667                0.048333
# 85                   108.083333                0.050500
#
#     team1_PStat_lag180_TOV_RANK  team1_PStat_lag180_W_PCT  \
# 33                   190.444444                  0.631333
# 28                   239.800000                  0.673100
# 18                   238.777778                  0.492333
# 38                   304.250000                  0.681417
# 24                   203.250000                  0.613250
# ..                          ...                       ...
# 81                   121.185185                  0.670481
# 82                   129.966667                  0.690800
# 83                   113.159091                  0.662341
# 84                   115.383333                  0.662083
# 85                   109.513636                  0.650192
#
#     team1_PStat_lag180_W_PCT_RANK  team1_PStat_lag32_AST  \
# 33                     115.666667               0.096667
# 28                      78.800000               0.078000
# 18                     229.222222               0.077778
# 38                      77.000000               0.073333
# 24                     132.500000               0.106250
# ..                            ...                    ...
# 81                      35.333333               0.074815
# 82                      32.466667               0.077333
# 83                      33.909091               0.076818
# 84                      35.158333               0.073083
# 85                      34.000000               0.067258
#
#     team1_PStat_lag32_AST_RANK  team1_PStat_lag32_BLK  team1_PStat_lag32_DREB  \
# 33                  172.111111               0.027778                0.145556
# 28                  247.400000               0.017000                0.113000
# 18                  204.555556               0.028889                0.136667
# 38                  216.083333               0.016667                0.130000
# 24                  137.625000               0.023750                0.133750
# ..                         ...                    ...                     ...
# 81                   76.074074               0.025185                0.122593
# 82                   82.233333               0.023333                0.120333
# 83                   73.568182               0.022273                0.121364
# 84                   68.858333               0.017417                0.122000
# 85                   70.139394               0.018000                0.133530
#
#     team1_PStat_lag32_DREB_RANK  team1_PStat_lag32_FG3M  \
# 33                   172.111111                0.027778
# 28                   222.900000                0.026000
# 18                   165.000000                0.016667
# 38                   190.916667                0.031667
# 24                   189.875000                0.038750
# ..                          ...                     ...
# 81                    84.666667                0.021852
# 82                    89.500000                0.031667
# 83                    79.386364                0.026136
# 84                    72.941667                0.027917
# 85                    59.719697                0.022727
#
#     team1_PStat_lag32_FG3M_RANK  team1_PStat_lag32_FG3_PCT  \
# 33                   157.666667                   0.256000
# 28                   166.000000                   0.235200
# 18                   193.888889                   0.187111
# 38                   167.583333                   0.178083
# 24                   135.625000                   0.329000
# ..                          ...                        ...
# 81                    55.592593                   0.208185
# 82                    50.966667                   0.236500
# 83                    52.386364                   0.207727
# 84                    47.333333                   0.232400
# 85                    47.622727                   0.172427
#
#     team1_PStat_lag32_FG3_PCT_RANK  team1_PStat_lag32_FGM_RANK  \
# 33                      150.777778                  161.888889
# 28                      150.900000                  196.500000
# 18                      185.444444                  216.888889
# 38                      183.166667                  174.583333
# 24                      124.125000                  142.875000
# ..                             ...                         ...
# 81                       54.370370                   85.370370
# 82                       50.933333                   78.933333
# 83                       52.159091                   77.477273
# 84                       45.616667                   68.175000
# 85                       47.754545                   67.428788
#
#     team1_PStat_lag32_FG_PCT  team1_PStat_lag32_FG_PCT_RANK  \
# 33                  0.505333                     119.444444
# 28                  0.486900                     158.200000
# 18                  0.433333                     211.888889
# 38                  0.490500                     149.833333
# 24                  0.498250                     115.875000
# ..                       ...                            ...
# 81                  0.437259                      73.555556
# 82                  0.449133                      76.266667
# 83                  0.444273                      68.227273
# 84                  0.404267                      68.700000
# 85                  0.449144                      65.563636
#
#     team1_PStat_lag32_FTM  team1_PStat_lag32_FT_PCT  \
# 33               0.075556                  0.791889
# 28               0.069000                  0.700200
# 18               0.068889                  0.672000
# 38               0.060000                  0.607917
# 24               0.092500                  0.742000
# ..                    ...                       ...
# 81               0.075926                  0.641926
# 82               0.073667                  0.574867
# 83               0.096364                  0.688091
# 84               0.089750                  0.585275
# 85               0.094712                  0.649726
#
#     team1_PStat_lag32_FT_PCT_RANK  team1_PStat_lag32_GP  \
# 33                     135.111111             14.666667
# 28                     204.900000             15.300000
# 18                     210.666667             13.555556
# 38                     222.000000             13.583333
# 24                     197.250000             15.875000
# ..                            ...                   ...
# 81                      64.407407              9.148148
# 82                      74.366667              8.333333
# 83                      54.181818              8.909091
# 84                      58.433333              8.425000
# 85                      58.010606              8.496970
#
#     team1_PStat_lag32_NBA_FANTASY_PTS  team1_PStat_lag32_NBA_FANTASY_PTS_RANK  \
# 33                           0.901111                              163.333333
# 28                           0.838000                              206.000000
# 18                           0.830000                              205.888889
# 38                           0.810833                              204.416667
# 24                           0.983750                              101.625000
# ..                                ...                                     ...
# 81                           0.800000                               84.000000
# 82                           0.879667                               73.600000
# 83                           0.843182                               70.068182
# 84                           0.813833                               65.241667
# 85                           0.809152                               70.406061
#
#     team1_PStat_lag32_OREB  team1_PStat_lag32_OREB_RANK  \
# 33                0.040000                   212.555556
# 28                0.045000                   199.500000
# 18                0.062222                   151.555556
# 38                0.054167                   193.500000
# 24                0.038750                   206.875000
# ..                     ...                          ...
# 81                0.050370                    73.740741
# 82                0.044000                    80.833333
# 83                0.041818                    75.295455
# 84                0.039500                    72.558333
# 85                0.046909                    62.356061
#
#     team1_PStat_lag32_PLUS_MINUS  team1_PStat_lag32_PLUS_MINUS_RANK  \
# 33                      0.104444                         117.888889
# 28                      0.101000                         118.400000
# 18                     -0.001111                         195.333333
# 38                      0.088333                         147.083333
# 24                      0.098750                         128.125000
# ..                           ...                                ...
# 81                      0.033704                          73.925926
# 82                      0.117333                          66.066667
# 83                      0.058864                          67.204545
# 84                      0.045667                          60.483333
# 85                      0.127818                          47.400000
#
#     team1_PStat_lag32_PTS  team1_PStat_lag32_PTS_RANK  team1_PStat_lag32_STL  \
# 33               0.432222                  173.666667               0.023333
# 28               0.394000                  194.200000               0.042000
# 18               0.363333                  222.666667               0.024444
# 38               0.398333                  185.166667               0.025833
# 24               0.486250                  141.500000               0.037500
# ..                    ...                         ...                    ...
# 81               0.358889                   83.629630               0.031481
# 82               0.394333                   78.200000               0.053000
# 83               0.391591                   69.772727               0.041591
# 84               0.385000                   63.675000               0.040417
# 85               0.392439                   63.743939               0.034712
#
#     team1_PStat_lag32_STL_RANK  team1_PStat_lag32_TOV  \
# 33                  226.444444               0.060000
# 28                  146.800000               0.044000
# 18                  214.000000               0.048889
# 38                  208.000000               0.042500
# 24                  123.250000               0.052500
# ..                         ...                    ...
# 81                   60.074074               0.048519
# 82                   51.033333               0.054333
# 83                   53.500000               0.050000
# 84                   48.783333               0.047667
# 85                   50.918182               0.058682
#
#     team1_PStat_lag32_TOV_RANK  team1_PStat_lag32_W_PCT  \
# 33                  171.666667                 0.683000
# 28                  217.800000                 0.699800
# 18                  203.222222                 0.476111
# 38                  230.500000                 0.564833
# 24                  187.250000                 0.630250
# ..                         ...                      ...
# 81                   64.777778                 0.765704
# 82                   62.700000                 0.789133
# 83                   66.818182                 0.714227
# 84                   62.075000                 0.770583
# 85                   48.036364                 0.709750
#
#     team1_PStat_lag32_W_PCT_RANK  team1_PStat_lag64_AST  \
# 33                     90.888889               0.094444
# 28                     82.300000               0.075000
# 18                    210.555556               0.078889
# 38                    158.833333               0.075833
# 24                    120.000000               0.103750
# ..                           ...                    ...
# 81                      7.296296               0.083704
# 82                      5.533333               0.079667
# 83                     19.613636               0.083636
# 84                      9.066667               0.083333
# 85                     14.218182               0.069364
#
#     team1_PStat_lag64_AST_RANK  team1_PStat_lag64_BLK  team1_PStat_lag64_DREB  \
# 33                  185.888889               0.030000                0.143333
# 28                  261.400000               0.016000                0.117000
# 18                  211.222222               0.024444                0.138889
# 38                  220.250000               0.017500                0.138333
# 24                  142.500000               0.025000                0.133750
# ..                         ...                    ...                     ...
# 81                  107.370370               0.020370                0.122593
# 82                  121.266667               0.017667                0.119667
# 83                  105.204545               0.016591                0.118636
# 84                  101.041667               0.012917                0.113667
# 85                  121.739394               0.020742                0.127197
#
#     team1_PStat_lag64_DREB_RANK  team1_PStat_lag64_FG3M  \
# 33                   187.888889                0.027778
# 28                   226.900000                0.026000
# 18                   173.444444                0.022222
# 38                   180.583333                0.032500
# 24                   202.125000                0.036250
# ..                          ...                     ...
# 81                   119.111111                0.024444
# 82                   132.433333                0.032000
# 83                   130.136364                0.026818
# 84                   125.541667                0.029250
# 85                   107.400000                0.023500
#
#     team1_PStat_lag64_FG3M_RANK  team1_PStat_lag64_FG3_PCT  \
# 33                   169.777778                   0.260778
# 28                   180.100000                   0.249800
# 18                   190.444444                   0.195333
# 38                   169.583333                   0.182750
# 24                   154.750000                   0.363625
# ..                          ...                        ...
# 81                    97.740741                   0.207037
# 82                    88.600000                   0.230567
# 83                    95.590909                   0.207545
# 84                    84.883333                   0.237017
# 85                    93.813636                   0.184795
#
#     team1_PStat_lag64_FG3_PCT_RANK  team1_PStat_lag64_FGM_RANK  \
# 33                      160.777778                  161.777778
# 28                      160.200000                  201.900000
# ...
# 38          0.670000            0.478000             0.78700        7.000000
# 24          0.670000            0.491000             0.81200        7.000000
# ..               ...                 ...                 ...             ...
# 81          0.680000            0.477500             0.80800        3.000000
# 82          0.636667            0.464667             0.78700        3.666667
# 83          0.640000            0.461750             0.77925        4.000000
# 84          0.632500            0.456500             0.77625        4.000000
# 85          0.622000            0.455200             0.75380        4.200000
#
#     team2_lag16_OREB  team2_lag16_PLUS_MINUS  team2_lag16_PLUS_MINUS_RANK  \
# 33            0.1300               -0.010000                    15.000000
# 28            0.2300                0.140000                     9.000000
# 18            0.2900                0.040000                    13.000000
# 38            0.2200                0.170000                     6.000000
# 24            0.2300                0.270000                     1.000000
# ..               ...                     ...                          ...
# 81            0.2250                0.265000                     1.500000
# 82            0.2300                0.093333                     3.333333
# 83            0.2250                0.120000                     2.750000
# 84            0.2175                0.097500                     2.000000
# 85            0.2140                0.056000                     2.000000
#
#     team2_lag16_PTS  team2_lag16_PTS_RANK  team2_lag16_REB  team2_lag16_STL  \
# 33           1.8000                 30.00         0.820000         0.120000
# 28           2.1600                 10.00         0.890000         0.100000
# 18           2.1100                 15.00         0.910000         0.140000
# 38           2.0400                 20.00         0.890000         0.170000
# 24           2.3000                  3.00         0.900000         0.150000
# ..              ...                   ...              ...              ...
# 81           2.2600                  2.00         0.900000         0.190000
# 82           2.1600                  3.00         0.866667         0.176667
# 83           2.1150                  1.50         0.865000         0.162500
# 84           2.1075                  2.25         0.850000         0.170000
# 85           2.0840                  2.20         0.836000         0.166000
#
#     team2_lag16_TOV  team2_lag16_W_PCT  team2_lag16_W_PCT_RANK  \
# 33           0.2600              0.571               11.000000
# 28           0.1700              0.625                8.000000
# 18           0.2700              0.625                8.000000
# 38           0.2800              0.714                5.000000
# 24           0.2700              0.857                1.000000
# ..              ...                ...                     ...
# 81           0.2800              0.800                1.500000
# 82           0.2700              0.600                1.666667
# 83           0.2575              0.700                1.750000
# 84           0.2500              0.550                1.750000
# 85           0.2780              0.520                1.800000
#
#     team2_lag180_AST  team2_lag180_BLK  team2_lag180_DREB  \
# 33          0.440000          0.090000           0.660000
# 28          0.440000          0.100000           0.670000
# 18          0.400000          0.100000           0.600000
# 38          0.550000          0.090000           0.610000
# 24          0.510000          0.110000           0.690000
# ..               ...               ...                ...
# 81          0.475000          0.115000           0.660000
# 82          0.463333          0.116667           0.653333
# 83          0.450000          0.117500           0.650000
# 84          0.457500          0.110000           0.650000
# 85          0.454000          0.118000           0.648000
#
#     team2_lag180_FG_PCT  team2_lag180_FT_PCT  team2_lag180_GP  \
# 33              0.45700             0.761000            82.00
# 28              0.46400             0.814000            82.00
# 18              0.44600             0.782000            82.00
# 38              0.49700             0.759000            82.00
# 24              0.47600             0.769000            82.00
# ..                  ...                  ...              ...
# 81              0.47600             0.765000            39.00
# 82              0.47600             0.767333            32.00
# 83              0.47425             0.760000            28.75
# 84              0.47200             0.758750            29.00
# 85              0.47100             0.757000            27.60
#
#     team2_lag180_OREB  team2_lag180_PLUS_MINUS  team2_lag180_PLUS_MINUS_RANK  \
# 33           0.200000                 0.100000                      8.000000
# 28           0.220000                 0.090000                     10.000000
# 18           0.250000                -0.010000                     15.000000
# 38           0.240000                 0.140000                      4.000000
# 24           0.230000                 0.150000                      3.000000
# ..                ...                      ...                           ...
# 81           0.205000                 0.140000                      1.500000
# 82           0.203333                 0.123333                      1.333333
# 83           0.200000                 0.117500                      1.250000
# 84           0.200000                 0.110000                      2.000000
# 85           0.198000                 0.106000                      1.200000
#
#     team2_lag180_PTS  team2_lag180_PTS_RANK  team2_lag180_REB  \
# 33            1.9800                  26.00             0.860
# 28            2.0900                  11.00             0.890
# 18            2.0400                  14.00             0.860
# 38            2.2100                   5.00             0.850
# 24            2.2500                   4.00             0.920
# ..               ...                    ...               ...
# 81            2.2150                   2.50             0.870
# 82            2.2000                   2.00             0.850
# 83            2.1775                   1.75             0.850
# 84            2.1625                   1.75             0.850
# 85            2.1560                   1.60             0.844
#
#     team2_lag180_STL  team2_lag180_TOV  team2_lag180_W_PCT  \
# 33          0.130000          0.260000            0.683000
# 28          0.120000          0.260000            0.622000
# 18          0.160000          0.270000            0.524000
# 38          0.180000          0.300000            0.659000
# 24          0.170000          0.290000            0.695000
# ..               ...               ...                 ...
# 81          0.155000          0.270000            0.738000
# 82          0.153333          0.273333            0.712667
# 83          0.152500          0.272500            0.721750
# 84          0.152500          0.262500            0.695250
# 85          0.152000          0.270000            0.704800
#
#     team2_lag180_W_PCT_RANK  team2_lag32_AST  team2_lag32_BLK  \
# 33                 4.000000         0.420000         0.090000
# 28                10.000000         0.460000         0.100000
# 18                14.000000         0.440000         0.080000
# 38                 8.000000         0.550000         0.090000
# 24                 3.000000         0.550000         0.110000
# ..                      ...              ...              ...
# 81                 1.500000         0.525000         0.160000
# 82                 1.666667         0.476667         0.136667
# 83                 1.750000         0.452500         0.127500
# 84                 1.500000         0.460000         0.120000
# 85                 1.400000         0.438000         0.114000
#
#     team2_lag32_DREB  team2_lag32_FG_PCT  team2_lag32_FT_PCT  team2_lag32_GP  \
# 33          0.700000            0.470000            0.775000       16.000000
# 28          0.670000            0.459000            0.811000       15.000000
# 18          0.570000            0.461000            0.747000       17.000000
# 38          0.630000            0.505000            0.757000       14.000000
# 24          0.680000            0.475000            0.804000       16.000000
# ..               ...                 ...                 ...             ...
# 81          0.655000            0.486000            0.817500        6.000000
# 82          0.636667            0.477333            0.804333        7.666667
# 83          0.655000            0.471500            0.778500        8.500000
# 84          0.662500            0.467750            0.789750        8.500000
# 85          0.670000            0.464000            0.777000        9.000000
#
#     team2_lag32_OREB  team2_lag32_PLUS_MINUS  team2_lag32_PLUS_MINUS_RANK  \
# 33            0.1600                0.150000                          5.0
# 28            0.2100                0.050000                         12.0
# 18            0.2500               -0.030000                         17.0
# 38            0.2500                0.230000                          1.0
# 24            0.2400                0.170000                          4.0
# ..               ...                     ...                          ...
# 81            0.2200                0.260000                          2.0
# 82            0.2100                0.166667                          4.0
# 83            0.2025                0.142500                          2.0
# 84            0.2025                0.150000                          2.0
# 85            0.1980                0.120000                          2.0
#
#     team2_lag32_PTS  team2_lag32_PTS_RANK  team2_lag32_REB  team2_lag32_STL  \
# 33         1.970000             25.000000         0.860000         0.110000
# 28         2.090000             16.000000         0.880000         0.120000
# 18         2.070000             20.000000         0.820000         0.140000
# 38         2.190000              7.000000         0.880000         0.170000
# 24         2.290000              3.000000         0.920000         0.150000
# ..              ...                   ...              ...              ...
# 81         2.330000              2.500000         0.875000         0.190000
# 82         2.226667              2.333333         0.846667         0.176667
# 83         2.160000              2.250000         0.857500         0.162500
# 84         2.145000              2.250000         0.865000         0.162500
# 85         2.100000              2.200000         0.868000         0.166000
#
#     team2_lag32_TOV  team2_lag32_W_PCT  team2_lag32_W_PCT_RANK  \
# 33         0.240000           0.750000                2.000000
# 28         0.230000           0.467000               16.000000
# 18         0.250000           0.588000               10.000000
# 38         0.280000           0.714000                4.000000
# 24         0.250000           0.750000                3.000000
# ..              ...                ...                     ...
# 81         0.290000           0.818000                1.500000
# 82         0.276667           0.696667                1.666667
# 83         0.272500           0.727000                1.000000
# 84         0.272500           0.727000                1.750000
# 85         0.270000           0.708800                1.000000
#
#     team2_lag64_AST  team2_lag64_BLK  team2_lag64_DREB  team2_lag64_FG_PCT  \
# 33         0.420000         0.090000          0.680000            0.456000
# 28         0.470000         0.100000          0.690000            0.466000
# 18         0.420000         0.100000          0.580000            0.451000
# 38         0.560000         0.090000          0.620000            0.509000
# 24         0.530000         0.120000          0.670000            0.475000
# ..              ...              ...               ...                 ...
# 81         0.490000         0.115000          0.655000            0.482500
# 82         0.476667         0.116667          0.656667            0.478667
# 83         0.460000         0.117500          0.652500            0.474250
# 84         0.477500         0.112500          0.660000            0.473500
# 85         0.472000         0.126000          0.660000            0.475200
#
#     team2_lag64_FT_PCT  team2_lag64_GP  team2_lag64_OREB  \
# 33            0.773000       31.000000          0.180000
# 28            0.804000       30.000000          0.230000
# 18            0.755000       30.000000          0.240000
# 38            0.773000       29.000000          0.240000
# 24            0.794000       30.000000          0.230000
# ..                 ...             ...               ...
# 81            0.787000       11.500000          0.205000
# 82            0.779667       13.333333          0.203333
# 83            0.767750       14.750000          0.200000
# 84            0.779750       15.000000          0.207500
# 85            0.773000       16.400000          0.204000
#
#     team2_lag64_PLUS_MINUS  team2_lag64_PLUS_MINUS_RANK  team2_lag64_PTS  \
# 33                   0.100                         9.00           1.9500
# 28                   0.110                         8.00           2.1200
# 18                  -0.020                        17.00           2.0400
# 38                   0.180                         4.00           2.2400
# 24                   0.180                         3.00           2.2900
# ..                     ...                          ...              ...
# 81                   0.190                         1.00           2.2350
# 82                   0.170                         1.00           2.2100
# 83                   0.145                         1.25           2.1825
# 84                   0.150                         1.75           2.1825
# 85                   0.164                         1.00           2.1840
#
#     team2_lag64_PTS_RANK  team2_lag64_REB  team2_lag64_STL  team2_lag64_TOV  \
# 33             28.000000         0.860000         0.130000         0.260000
# 28             10.000000         0.910000         0.130000         0.270000
# 18             23.000000         0.830000         0.160000         0.240000
# 38              5.000000         0.850000         0.160000         0.280000
# 24              4.000000         0.910000         0.160000         0.260000
# ..                   ...              ...              ...              ...
# 81              2.000000         0.865000         0.150000         0.265000
# 82              1.666667         0.853333         0.153333         0.273333
# 83              1.750000         0.852500         0.147500         0.265000
# 84              1.250000         0.867500         0.150000         0.267500
# 85              1.600000         0.864000         0.154000         0.274000
#
#     team2_lag64_W_PCT  team2_lag64_W_PCT_RANK  SEASON
# 33           0.710000                    4.00       1
# 28           0.533000                   13.00       1
# 18           0.600000                   10.00       1
# 38           0.690000                    5.00       1
# 24           0.733000                    3.00       1
# ..                ...                     ...     ...
# 81           0.803500                    1.00       1
# 82           0.748333                    1.00       1
# 83           0.741500                    1.25       1
# 84           0.763000                    1.00       1
# 85           0.760000                    1.00       1
#
# [86 rows x 469 columns]

# %%
team1_labels = []
team2_labels = []
for i in list(df_train_arr[0].columns):
  if "team1" in i:
    team1_labels.append(i)
  elif "team2" in i:
    team2_labels.append(i)


for i in team1_labels:
  if not f"team2{i[5:]}" in team2_labels:
    print(i)
# Out:
# team1_IS_HOME
# team1_W

# %%
team1_labels = []
team2_labels = []
for i in list(df_train_arr_v2[0].columns):
  if "team1" in i:
    team1_labels.append(i)
  elif "team2" in i:
    team2_labels.append(i)


for i in team1_labels:
  if not f"team2{i[5:]}" in team2_labels:
    print(i)
# Out:
# team1_IS_HOME
# team1_W

# %%
train = pd.concat(df_train_arr[:-2])
val = pd.concat(df_train_arr[-2:])

# %%
data_v2 = pd.concat(df_train_arr_v2).sort_values(by=["SEASON", "DATE_WITHIN_SEASON"])

# %%
pandemic_regular_idx = data_v2["DATE_WITHIN_SEASON"] > 200

# %%
max_within_season = data_v2.loc[pandemic_regular_idx, "DATE_WITHIN_SEASON"].max()

# %%
def shift_to(x, end_value: int = 180, max_value: int = max_within_season):
  return x - max_value + end_value

# %%
data_v2.loc[pandemic_regular_idx, "DATE_WITHIN_SEASON"] = shift_to(data_v2.loc[pandemic_regular_idx, "DATE_WITHIN_SEASON"])

# %%
fig, axs = plt.subplots(len(train.columns)-1, figsize=(10, 600))
n = 0
for col in train.columns:
  if col == "GAME_DATE":
    continue
  
  axs[n].set_title(col)
  train[col].hist(ax=axs[n], bins=100)
  n += 1

# %%
fig, axs = plt.subplots(len(data_v2.columns)//2 +1, 2, figsize=(12, 800))

for idx, col in enumerate(data_v2.columns):
  
  idx_1 = idx // 2 
  idx_2 = idx % 2
  axs[idx_1, idx_2].set_title(col)
  axs[idx_1, idx_2].hist(data_v2_normalized[:,idx], bins=100)

  data_v2[col].hist(ax=axs[idx_1, idx_2], bins=100)

# %%
# Set figure size
plt.figure(figsize=(20,20))

# Calculate correlation matrix
cor = data_v2.corr() 

# Plot the correlation matrix
#sns.heatmap(cor, annot=True, cmap=plt.cm.PuBu)
#plt.show()

# %%
# Get the absolute value of the correlation
cor_target = abs(cor["team1_W"])

# Select highly correlated features (thresold = 0.2)
relevant_features = cor_target[cor_target>0.05]

# Collect the names of the features
names = [index for index, value in relevant_features.iteritems()]

# Drop the target variable from the results
#names.remove('team1_W')

# Display the results
print(names, len(names))

names += ["SEASON", "DATE_WITHIN_SEASON"]
# Out:
# ['team1_IS_HOME', 'team1_L_cum', 'team1_PStat_lag08_FG_PCT_RANK', 'team1_PStat_lag08_PLUS_MINUS', 'team1_PStat_lag08_PLUS_MINUS_RANK', 'team1_PStat_lag08_W_PCT', 'team1_PStat_lag08_W_PCT_RANK', 'team1_PStat_lag16_FG3M_RANK', 'team1_PStat_lag16_FG_PCT', 'team1_PStat_lag16_FG_PCT_RANK', 'team1_PStat_lag16_PLUS_MINUS', 'team1_PStat_lag16_PLUS_MINUS_RANK', 'team1_PStat_lag16_W_PCT', 'team1_PStat_lag16_W_PCT_RANK', 'team1_PStat_lag180_AST', 'team1_PStat_lag180_FG3M_RANK', 'team1_PStat_lag180_FG3_PCT_RANK', 'team1_PStat_lag180_FG_PCT', 'team1_PStat_lag180_FG_PCT_RANK', 'team1_PStat_lag180_NBA_FANTASY_PTS', 'team1_PStat_lag180_NBA_FANTASY_PTS_RANK', 'team1_PStat_lag180_PLUS_MINUS', 'team1_PStat_lag180_PLUS_MINUS_RANK', 'team1_PStat_lag180_PTS', 'team1_PStat_lag180_PTS_RANK', 'team1_PStat_lag180_W_PCT', 'team1_PStat_lag180_W_PCT_RANK', 'team1_PStat_lag32_FG3M_RANK', 'team1_PStat_lag32_FG3_PCT_RANK', 'team1_PStat_lag32_FG_PCT', 'team1_PStat_lag32_FG_PCT_RANK', 'team1_PStat_lag32_NBA_FANTASY_PTS', 'team1_PStat_lag32_NBA_FANTASY_PTS_RANK', 'team1_PStat_lag32_PLUS_MINUS', 'team1_PStat_lag32_PLUS_MINUS_RANK', 'team1_PStat_lag32_W_PCT', 'team1_PStat_lag32_W_PCT_RANK', 'team1_PStat_lag64_FG3M_RANK', 'team1_PStat_lag64_FG3_PCT_RANK', 'team1_PStat_lag64_FG_PCT', 'team1_PStat_lag64_FG_PCT_RANK', 'team1_PStat_lag64_NBA_FANTASY_PTS', 'team1_PStat_lag64_NBA_FANTASY_PTS_RANK', 'team1_PStat_lag64_PLUS_MINUS', 'team1_PStat_lag64_PLUS_MINUS_RANK', 'team1_PStat_lag64_PTS', 'team1_PStat_lag64_W_PCT', 'team1_PStat_lag64_W_PCT_RANK', 'team1_W', 'team1_W_cum', 'team1_lag08_AST', 'team1_lag08_FG_PCT', 'team1_lag08_PLUS_MINUS', 'team1_lag08_PLUS_MINUS_RANK', 'team1_lag08_PTS', 'team1_lag08_PTS_RANK', 'team1_lag08_W_PCT', 'team1_lag08_W_PCT_RANK', 'team1_lag16_AST', 'team1_lag16_BLK', 'team1_lag16_FG_PCT', 'team1_lag16_PLUS_MINUS', 'team1_lag16_PLUS_MINUS_RANK', 'team1_lag16_PTS', 'team1_lag16_PTS_RANK', 'team1_lag16_W_PCT', 'team1_lag16_W_PCT_RANK', 'team1_lag180_AST', 'team1_lag180_BLK', 'team1_lag180_DREB', 'team1_lag180_FG_PCT', 'team1_lag180_PLUS_MINUS', 'team1_lag180_PLUS_MINUS_RANK', 'team1_lag180_PTS', 'team1_lag180_PTS_RANK', 'team1_lag180_TOV', 'team1_lag180_W_PCT', 'team1_lag180_W_PCT_RANK', 'team1_lag32_AST', 'team1_lag32_BLK', 'team1_lag32_FG_PCT', 'team1_lag32_PLUS_MINUS', 'team1_lag32_PLUS_MINUS_RANK', 'team1_lag32_PTS', 'team1_lag32_PTS_RANK', 'team1_lag32_TOV', 'team1_lag32_W_PCT', 'team1_lag32_W_PCT_RANK', 'team1_lag64_AST', 'team1_lag64_BLK', 'team1_lag64_FG_PCT', 'team1_lag64_PLUS_MINUS', 'team1_lag64_PLUS_MINUS_RANK', 'team1_lag64_PTS', 'team1_lag64_PTS_RANK', 'team1_lag64_STL', 'team1_lag64_TOV', 'team1_lag64_W_PCT', 'team1_lag64_W_PCT_RANK', 'team2_L_cum', 'team2_PStat_lag08_AST', 'team2_PStat_lag08_FG3M', 'team2_PStat_lag08_FG_PCT', 'team2_PStat_lag08_FG_PCT_RANK', 'team2_PStat_lag08_PLUS_MINUS', 'team2_PStat_lag08_PLUS_MINUS_RANK', 'team2_PStat_lag08_PTS', 'team2_PStat_lag08_W_PCT', 'team2_PStat_lag08_W_PCT_RANK', 'team2_PStat_lag16_AST', 'team2_PStat_lag16_FG3M', 'team2_PStat_lag16_FG_PCT', 'team2_PStat_lag16_FG_PCT_RANK', 'team2_PStat_lag16_NBA_FANTASY_PTS', 'team2_PStat_lag16_NBA_FANTASY_PTS_RANK', 'team2_PStat_lag16_PLUS_MINUS', 'team2_PStat_lag16_PLUS_MINUS_RANK', 'team2_PStat_lag16_PTS', 'team2_PStat_lag16_W_PCT', 'team2_PStat_lag16_W_PCT_RANK', 'team2_PStat_lag180_AST', 'team2_PStat_lag180_FG3M', 'team2_PStat_lag180_FG3_PCT', 'team2_PStat_lag180_FG_PCT', 'team2_PStat_lag180_FG_PCT_RANK', 'team2_PStat_lag180_NBA_FANTASY_PTS', 'team2_PStat_lag180_NBA_FANTASY_PTS_RANK', 'team2_PStat_lag180_PLUS_MINUS', 'team2_PStat_lag180_PLUS_MINUS_RANK', 'team2_PStat_lag180_PTS', 'team2_PStat_lag180_W_PCT', 'team2_PStat_lag180_W_PCT_RANK', 'team2_PStat_lag32_AST', 'team2_PStat_lag32_FG3M', 'team2_PStat_lag32_FG3_PCT', 'team2_PStat_lag32_FG_PCT', 'team2_PStat_lag32_FG_PCT_RANK', 'team2_PStat_lag32_NBA_FANTASY_PTS', 'team2_PStat_lag32_NBA_FANTASY_PTS_RANK', 'team2_PStat_lag32_PLUS_MINUS', 'team2_PStat_lag32_PLUS_MINUS_RANK', 'team2_PStat_lag32_PTS ...

# %%
data_v2 = data_v2[names]

# %%
def objective_hyperparam(trial):

    # Dictionary to map from parameter name to values
    params = {
        'n_estimators': trial.suggest_int("n_estimators", 64, 1024),
        'eta': trial.suggest_float("eta", 0.001, 0.9, log=True),
        'max_depth': trial.suggest_int("max_depth", 1, 15, step=1),
        'min_child_weight': trial.suggest_float("min_child_weight", 0.3, 1.2, step=0.1),
        #'eval_metric': ["binary:logistic"],
        'colsample_bytree': trial.suggest_float("colsample_bytree", 0.3, 0.9, step=0.1), 
        'subsample':trial.suggest_float("subsample", 0.3, 0.9, step=0.1), 
        #'early_stopping_rounds': 15,
        'seed': trial.suggest_int("seed", 42, 43),
        'verbose' : False,
    }
    
    # XGboost model
    model = xgb.XGBClassifier(
        max_depth=params['max_depth'],
        n_estimators=params['n_estimators'],
        min_child_weight=params['min_child_weight'], 
        colsample_bytree=params['colsample_bytree'], 
        subsample=params['subsample'], 
        eta=params['eta'],
        tree_method='gpu_hist',
        seed=params['seed'],
        n_jobs=4)
    
    split_num = 1
    
    total_score = 0

    # Calculate score of model by taking weighted average over 5 splits
    for i in range(split_num):
        

        regular_idx = (data_v2["SEASON"]%2 == 0) #& (data_v2["SEASON"] > 10)


        val_idx = (data_v2["DATE_WITHIN_SEASON"] > 155) #& (data_v2["SEASON"]%4 == 0) #& (data_v2["SEASON"] == 28)
        train_idx = ~val_idx

        X_train = data_v2.loc[regular_idx&train_idx,:]
        y_train = X_train.pop("team1_W")


        X_val = data_v2.loc[regular_idx&val_idx,:]
        y_val = X_val.pop("team1_W")

        # Apply min-max normalization
        #scaler = MinMaxScaler().fit(X_train)
        #scaler = StandardScaler().fit(X_train)
        #X_train = scaler.transform(X_train)
        #X_val = scaler.transform(X_val)


        model.fit(
            X_train, 
            y_train, 
            #eval_metric=params["eval_metric"], 
            eval_set=[(X_train, y_train), (X_val,y_val)], 
            verbose=params['verbose'], 
            early_stopping_rounds = 8)


        # Predictions
        yhat_val = model.predict(X_val)

        # Accuracy
        accuracy = (yhat_val == y_val).sum() / len(y_val)

        
        total_score += accuracy
    
    # Take the averegge
    total_score = total_score / split_num
    
    return total_score

# %%
# Study object to optimize objective_hyperparam function
study_01 = optuna.create_study(direction="maximize")
study_01.optimize(objective_hyperparam, n_trials=10)

version = "v1"
joblib.dump(study_01, f"./study_xgboost_hyparam_{version}.hyp")
# Out:
# [I 2022-06-09 10:53:42,850] A new study created in memory with name: no-name-156f5fbb-5860-4640-8e48-a95bda692a78
# [I 2022-06-09 10:53:44,025] Trial 0 finished with value: 0.6559422193040052 and parameters: {'n_estimators': 554, 'eta': 0.1943565351394589, 'max_depth': 11, 'min_child_weight': 0.9000000000000001, 'colsample_bytree': 0.9, 'subsample': 0.4, 'seed': 42}. Best is trial 0 with value: 0.6559422193040052.
# [I 2022-06-09 10:53:45,620] Trial 1 finished with value: 0.6585686145764937 and parameters: {'n_estimators': 95, 'eta': 0.006285919719410498, 'max_depth': 13, 'min_child_weight': 0.7, 'colsample_bytree': 0.8, 'subsample': 0.6000000000000001, 'seed': 42}. Best is trial 1 with value: 0.6585686145764937.
# [I 2022-06-09 10:53:45,937] Trial 2 finished with value: 0.6664478003939593 and parameters: {'n_estimators': 712, 'eta': 0.002022583558858939, 'max_depth': 5, 'min_child_weight': 1.2, 'colsample_bytree': 0.4, 'subsample': 0.8, 'seed': 43}. Best is trial 2 with value: 0.6664478003939593.
# [I 2022-06-09 10:53:46,264] Trial 3 finished with value: 0.680236375574524 and parameters: {'n_estimators': 108, 'eta': 0.057475278187207504, 'max_depth': 5, 'min_child_weight': 0.3, 'colsample_bytree': 0.7, 'subsample': 0.9, 'seed': 43}. Best is trial 3 with value: 0.680236375574524.
# [I 2022-06-09 10:53:47,267] Trial 4 finished with value: 0.6506894287590282 and parameters: {'n_estimators': 673, 'eta': 0.002990723891784971, 'max_depth': 12, 'min_child_weight': 0.4, 'colsample_bytree': 0.6000000000000001, 'subsample': 0.3, 'seed': 42}. Best is trial 3 with value: 0.680236375574524.
# [I 2022-06-09 10:53:49,080] Trial 5 finished with value: 0.6460932370321734 and parameters: {'n_estimators': 471, 'eta': 0.004165801234170775, 'max_depth': 13, 'min_child_weight': 0.3, 'colsample_bytree': 0.8, 'subsample': 0.8, 'seed': 42}. Best is trial 3 with value: 0.680236375574524.
# [I 2022-06-09 10:53:49,386] Trial 6 finished with value: 0.6657912015758372 and parameters: {'n_estimators': 569, 'eta': 0.003447003698197894, 'max_depth': 4, 'min_child_weight': 0.8, 'colsample_bytree': 0.5, 'subsample': 0.9, 'seed': 43}. Best is trial 3 with value: 0.680236375574524.
# [I 2022-06-09 10:53:49,691] Trial 7 finished with value: 0.6782665791201575 and parameters: {'n_estimators': 240, 'eta': 0.07764360321010594, 'max_depth': 2, 'min_child_weight': 1.1, 'colsample_bytree': 0.5, 'subsample': 0.3, 'seed': 43}. Best is trial 3 with value: 0.680236375574524.
# [I 2022-06-09 10:53:50,001] Trial 8 finished with value: 0.6841759684832567 and parameters: {'n_estimators': 411, 'eta': 0.05820858995258255, 'max_depth': 4, 'min_child_weight': 0.9000000000000001, 'colsample_bytree': 0.7, 'subsample': 0.8, 'seed': 43}. Best is trial 8 with value: 0.6841759684832567.
# [I 2022-06-09 10:53:50,327] Trial 9 finished with value: 0.6677609980302035 and parameters: {'n_estimators': 944, 'eta': 0.00125251247079889, 'max_depth': 5, 'min_child_weight': 0.8, 'colsample_bytree': 0.5, 'subsample': 0.4, 'seed': 43}. Best is trial 8 with value: 0.6841759684832567.
# ['./study_01.pkl']

# %%
study_hyper = joblib.load('./study_01.pkl')

# %%
study_hyper.best_params
# Out:
# {'colsample_bytree': 0.7,
#  'eta': 0.05820858995258255,
#  'max_depth': 4,
#  'min_child_weight': 0.9000000000000001,
#  'n_estimators': 411,
#  'seed': 43,
#  'subsample': 0.8}

# %%
# Dictionary to map from parameter name to values
params = study_hyper.best_params

params["verbose"] = False

# XGboost model
model = xgb.XGBClassifier(
    max_depth=params['max_depth'],
    n_estimators=params['n_estimators'],
    min_child_weight=params['min_child_weight'], 
    colsample_bytree=params['colsample_bytree'], 
    subsample=params['subsample'], 
    eta=params['eta'],
    tree_method='gpu_hist',
    seed=params['seed'],
    n_jobs=4)

split_num = 1

total_score = 0

season_arr = [22, 24, 26, 28]

# Calculate score of model by taking weighted average over 5 splits
for i in range(split_num):
    

    regular_idx = data_v2["SEASON"].isin(season_arr)


    val_idx = (data_v2["DATE_WITHIN_SEASON"] > 155) & (data_v2["SEASON"] == season_arr[-1])
    train_idx = ~val_idx

    X_train = data_v2.loc[regular_idx&train_idx,:]
    y_train = X_train.pop("team1_W")


    X_val = data_v2.loc[regular_idx&val_idx,:]
    y_val = X_val.pop("team1_W")

    # Apply min-max normalization
    #scaler = MinMaxScaler().fit(X_train)
    #scaler = StandardScaler().fit(X_train)
    #X_train = scaler.transform(X_train)
    #X_val = scaler.transform(X_val)


    model.fit(
        X_train, 
        y_train, 
        #eval_metric=params["eval_metric"], 
        eval_set=[(X_train, y_train), (X_val,y_val)], 
        verbose=params['verbose'],)
        #early_stopping_rounds = 8)


    # Predictions
    yhat_val = model.predict(X_val)

    # Accuracy
    accuracy = (yhat_val == y_val).sum() / len(y_val)

    
    total_score += accuracy

# Take the averegge
total_score = total_score / split_num

# %%
# XGboost model
model = xgb.XGBClassifier(
    max_depth=params['max_depth'],
    n_estimators=params['n_estimators'],
    min_child_weight=params['min_child_weight'], 
    colsample_bytree=params['colsample_bytree'], 
    subsample=params['subsample'], 
    eta=params['eta'],
    tree_method='gpu_hist',
    seed=params['seed'],
    n_jobs=4,
    early_stop=8)


season_arr = [12, 14, 16, 18]
val_end = int(data_v2.loc[data_v2["SEASON"]==season_arr[-1], "DATE_WITHIN_SEASON"].max())
val_start = int(val_end*0.90)
print(val_end)

val_day_arr = list(range(val_start+1, val_start+2))

total_score = 0
total_preds = 0

# Calculate score of model by taking weighted average over 5 splits
for val_day in val_day_arr:
    #print(f"Current val_day: {val_day}")


    regular_idx = (data_v2["SEASON"].isin(season_arr))


    val_idx = (data_v2["DATE_WITHIN_SEASON"] >= val_day) & (data_v2["SEASON"] == season_arr[-1])
    train_idx = (data_v2["DATE_WITHIN_SEASON"] < val_day) | (data_v2["SEASON"] != season_arr[-1])

    X_train = data_v2.loc[regular_idx&train_idx,:]
    y_train = X_train.pop("team1_W")


    X_val = data_v2.loc[regular_idx&val_idx,:]
    y_val = X_val.pop("team1_W")
    
    if X_val.shape[0] < 1:
      print("No game is played at this day, and skipping to the next day...")
      continue


    model.fit(
        X_train, 
        y_train, 
        #eval_metric=params["eval_metric"], 
        eval_set=[(X_train, y_train), (X_val,y_val)], 
        verbose=params['verbose'],)


    # Predictions
    yhat_val = model.predict(X_val)

    # Number of correct pred
    current_score = (yhat_val == y_val).sum()
    total_score += current_score
    
    # Number of preds
    current_preds = len(y_val)
    total_preds += current_preds


    
# Take the average
total_acc = total_score / total_preds
# Out:
# 169

# %%
model.save_model("model_01.xgb")

# %%
reg_xgb = xgb.Booster()
reg_xgb.load_model("model_01.xgb")

# %%
print(total_acc)
# Out:
# 0.6296296296296297

# %%
data_v2.loc[regular_idx,:]
# Out:
#       team1_IS_HOME  team1_L_cum  team1_PStat_lag08_FG_PCT_RANK  \
# 0               1.0          0.0                     171.500000
# 1               1.0          0.0                     175.166667
# 12              0.0          0.0                     125.875000
# 11              0.0          0.0                     160.000000
# 10              1.0          0.0                     187.875000
# ...             ...          ...                            ...
# 1216            0.0          2.0                     198.916667
# 1215            1.0          0.0                     226.250000
# 1228            1.0          1.0                     219.900000
# 1221            1.0          1.0                      94.777778
# 1229            1.0          3.0                     265.888889
#
#       team1_PStat_lag08_PLUS_MINUS  team1_PStat_lag08_PLUS_MINUS_RANK  \
# 0                         0.109167                         152.166667
# 1                        -0.736667                         241.416667
# 12                       -0.245000                         207.125000
# 11                       -0.537000                         168.100000
# 10                        0.056250                         144.875000
# ...                            ...                                ...
# 1216                     -0.253333                         257.166667
# 1215                      0.143750                         140.500000
# 1228                      0.029000                         215.500000
# 1221                      0.328889                          84.666667
# 1229                     -0.550000                         359.888889
#
#       team1_PStat_lag08_W_PCT  team1_PStat_lag08_W_PCT_RANK  \
# 0                    0.250000                    188.500000
# 1                    0.166667                    163.166667
# 12                   0.187500                    161.875000
# 11                   0.400000                     79.000000
# 10                   0.750000                     65.500000
# ...                       ...                           ...
# 1216                 0.241667                    295.666667
# 1215                 0.781250                     88.500000
# 1228                 0.349900                    268.200000
# 1221                 0.888889                     34.888889
# 1229                 0.000000                    338.000000
#
#       team1_PStat_lag16_FG3M_RANK  team1_PStat_lag16_FG_PCT  \
# 0                      139.666667                  0.398750
# 1                      143.000000                  0.401917
# 12                     163.125000                  0.526875
# 11                     118.600000                  0.498800
# 10                     113.000000                  0.305625
# ...                           ...                       ...
# 1216                   253.833333                  0.448500
# 1215                   199.250000                  0.465000
# 1228                   208.900000                  0.421600
# 1221                   173.444444                  0.547333
# 1229                   167.777778                  0.394111
#
#       team1_PStat_lag16_FG_PCT_RANK  team1_PStat_lag16_PLUS_MINUS  \
# 0                        186.750000                      0.059167
# 1                        174.416667                     -0.736667
# 12                       154.375000                     -0.282500
# 11                       132.700000                     -0.187000
# 10                       191.000000                      0.056250
# ...                             ...                           ...
# 1216                     215.833333                     -0.231667
# 1215                     222.875000                      0.068750
# 1228                     240.800000                      0.079000
# 1221                     108.555556                      0.166667
# 1229                     288.666667                     -0.413333
#
#       team1_PStat_lag16_PLUS_MINUS_RANK  team1_PStat_lag16_W_PCT  \
# 0                            164.750000                 0.375000
# 1                            240.750000                 0.166667
# 12                           219.875000                 0.062500
# 11                           161.100000                 0.350000
# 10                           150.000000                 0.750000
# ...                                 ...                      ...
# 1216                         269.916667                 0.306167
# 1215                         157.750000                 0.658000
# 1228                         220.000000                 0.460800
# 1221                         125.000000                 0.665222
# 1229                         381.111111                 0.000000
#
#       team1_PStat_lag16_W_PCT_RANK  team1_PStat_lag180_AST  \
# 0                       154.583333                0.080000
# 1                       163.166667                0.105000
# 12                      206.500000                0.112500
# 11                       95.600000                0.113000
# 10                       71.750000                0.093750
# ...                            ...                     ...
# 1216                    297.750000                0.090833
# 1215                    138.000000                0.088750
# 1228                    235.500000                0.107000
# 1221                    114.555556                0.083333
# 1229                    378.000000                0.072222
#
#       team1_PStat_lag180_FG3M_RANK  team1_PStat_lag180_FG3_PCT_RANK  \
# 0                       210.666667                       192.166667
# 1                       231.083333                       236.750000
# 12                      216.250000                       242.125000
# 11                      230.300000                       233.900000
# 10                      244.250000                       235.125000
# ...                            ...                              ...
# 1216                    331.833333                       298.666667
# 1215                    282.000000                       242.500000
# 1228                    290.700000                       275.100000
# 1221                    287.222222                       205.555556
# 1229                    238.777778                       321.888889
#
#       team1_PStat_lag180_FG_PCT  team1_PStat_lag180_FG_PCT_RANK  \
# 0                      0.453000                      240.916667
# 1                      0.497917                      151.000000
# 12                     0.469875                      254.875000
# 11                     0.490300                      197.200000
# 10                     0.425875                      306.375000
# ...                         ...                             ...
# 1216                   0.444750                      272.083333
# 1215                   0.495000                      211.500000
# 1228                   0.445500                      287.900000
# 1221                   0.468889                      276.222222
# 1229                   0.384444                      432.777778
#
#       team1_PStat_lag180_NBA_FANTASY_PTS  \
# 0                               0.835833
# 1                               0.898333
# 12                              0.882500
# 11                              0.967000
# 10                              0.793750
# ...                                  ...
# 1216                            0.778333
# 1215                            0.986250
# 1228                            0.858000
# 1221                            0.850000
# 1229                            0.760000
#
#       team1_PStat_lag180_NBA_FANTASY_PTS_RANK  team1_PStat_lag180_PLUS_MINUS  \
# 0                                  244.916667                       0.090833
# 1                                  243.000000                       0.011667
# 12                                 228.750000                      -0.072500
# 11                                 179.900000                      -0.035000
# 10                                 292.625000                      -0.058750
# ...                                       ...                            ...
# 1216                               369.916667                      -0.165833
# 1215                               225.750000                       0.006250
# 1228                               307.400000                       0.155000
# 1221                               303.666667                      -0.027778
# 1229                               381.444444                      -0.424444
#
#       team1_PStat_lag180_PLUS_MINUS_RANK  team1_PStat_lag180_PTS  \
# 0                             153.583333                0.415000
# 1                             169.750000                0.434167
# 12                            315.250000                0.401250
# 11                            231.100000                0.450000
# 10                            299.125000                0.377500
# ...                                  ...                     ...
# 1216                          353.583333                0.357500
# 1215                          250.500000                0.485000
# 1228                          164.200000                0.370000
# 1221                          294.000000                0.381111
# 1229                          552.555556                0.372222
#
#       team1_PStat_lag180_PTS_RANK  team1_PStat_lag180_W_PCT  \
# 0                      244.000000                  0.557333
# 1                      264.416667                  0.693667
# 12                     244.375000                  0.354625
# 11                     192.600000                  0.583300
# 10                     274.500000                  0.396250
# ...                           ...                       ...
# 1216                   341.583333                  0.360333
# 1215                   226.125000                  0.517875
# 1228                   324.700000                  0.693900
# 1221                   309.666667                  0.525333
# 1229                   327.888889                  0.198222
#
#       team1_PStat_lag180_W_PCT_RANK  team1_PStat_lag32_FG3M_RANK  \
# 0                        158.583333                   133.250000
# 1                         89.916667                   142.500000
# 12                       372.125000                   142.500000
# 11                       174.800000                   124.200000
# 10                       329.250000                   116.875000
# ...                             ...                          ...
# 1216                     437.250000                   280.416667
# 1215                     285.875000                   221.625000
# 1228                     133.200000                   234.600000
# 1221                     276.333333                   209.000000
# 1229                     527.000000                   187.222222
#
#       team1_PStat_lag32_FG3_PCT_RANK  team1_PStat_lag32_FG_PCT  \
# 0                         121.500000                  0.419667
# 1                         144.000000                  0.397833
# 12                        160.625000                  0.542000
# 11                        115.600000                  0.498800
# 10                        115.000000                  0.305625
# ...                              ...                       ...
# 1216                      250.833333                  0.434917
# 1215                      210.750000                  0.501250
# 1228                      237.700000                  0.419800
# 1221                      120.000000                  0.495444
# 1229                      215.333333                  0.393444
#
#       team1_PStat_lag32_FG_PCT_RANK  team1_PStat_lag32_NBA_FANTASY_PTS  \
# 0                        168.833333                           1.021667
# 1                        177.750000                           0.738333
# 12                       150.500000                           0.943750
# 11                       132.300000                           0.834000
# 10                       194.750000                           0.742500
# ...                             ...                                ...
# 1216                     229.500000                           0.735833
# 1215                     188.125000                           1.001250
# 1228                     254.400000                           0.863000
# 1221                     175.111111                           0.902222
# 1229                     317.000000                           0.794444
#
#       team1_PStat_lag32_NBA_FANTASY_PTS_RANK  team1_PStat_lag32_PLUS_MINUS  \
# 0                                 140.833333                      0.120833
# 1                                 218.000000                     -0.737500
# 12                                148.750000                     -0.343750
# 11                                151.100000                     -0.187000
# 10                                199.625000                      0.056250
# ...                                      ...                           ...
# 1216                              283.666667                     -0.257500
# 1215                              182.750000                      0.121250
# 1228                              252.600000                      0.069000
# 1221                              225.000000                     -0.045556
# 1229                              296.777778                     -0.438889
#
#       team1_PStat_lag32_PLUS_MINUS_RANK  team1_PStat_lag32_W_PCT  \
# 0                            129.166667                 0.441417
# 1                            240.500000                 0.166667
# 12                           254.250000                 0.041625
# 11                           165.900000                 0.350000
# 10                           154.125000                 0.750000
# ...                                 ...                      ...
# 1216                         312.166667                 0.203750
# 1215                         121.750000                 0.693500
# 1228                         208.700000                 0.691200
# 1221                         243.000000                 0.518889
# 1229                         426.111111                 0.085444
#
#       team1_PStat_lag32_W_PCT_RANK  team1_PStat_lag64_FG3M_RANK  \
# 0                       128.416667                   189.083333
# 1                       163.166667                   181.666667
# 12                      220.125000                   150.750000
# 11                       98.300000                   198.700000
# 10                       75.875000                   182.625000
# ...                            ...                          ...
# 1216                    379.750000                   275.083333
# 1215                    111.000000                   232.750000
# 1228                    121.400000                   243.500000
# 1221                    241.000000                   241.555556
# 1229                    433.888889                   216.000000
#
#       team1_PStat_lag64_FG3_PCT_RANK  team1_PStat_lag64_FG_PCT  \
# 0                         181.833333                  0.446250
# 1                         198.250000                  0.470250
# 12                        180.875000                  0.476125
# 11                        189.700000                  0.527000
# 10                        192.750000                  0.337625
# ...                              ...                       ...
# 1216                      227.500000                  0.439000
# 1215                      229.500000                  0.488375
# 1228                      228.800000                  0.437400
# 1221                      150.888889                  0.494333
# 1229                      272.555556                  0.381444
#
#       team1_PStat_lag64_FG_PCT_RANK  team1_PStat_lag64_NBA_FANTASY_PTS  \
# 0                        187.583333                           0.899167
# 1                        171.750000                           0.851667
# 12                       205.125000                           0.997500
# 11                       147.600000                           0.934000
# 10                       277.750000                           0.738750
# ...                             ...                                ...
# 1216                     236.416667                           0.749167
# 1215                     208.875000                           1.002500
# 1228                     258.000000                           0.870000
# 1221                     192.333333                           0.912222
# 1229                     366.333333                           0.773333
#
#       team1_PStat_lag64_NBA_FANTASY_PTS_RANK  team1_PStat_lag64_PLUS_MINUS  \
# 0                                 197.500000                      0.074167
# 1                                 223.000000                     -0.339167
# 12                                147.625000                     -0.246250
# 11                                181.300000                      0.170000
# 10                                250.750000                     -0.017500
# ...                                      ...                           ...
# 1216                              298.166667                     -0.249167
# 1215                              187.750000                      0.021250
# 1228                              268.500000                      0.114000
# 1221                              227.555556                     -0.041111
# 1229                              326.777778                     -0.443333
#
#       team1_PStat_lag64_PLUS_MINUS_RANK  team1_PStat_lag64_PTS  \
# 0                            184.000000               0.422500
# 1                            256.916667               0.460833
# 12                           290.625000               0.448750
# 11                           147.300000               0.547000
# 10                           212.250000               0.345000
# ...                                 ...                    ...
# 1216                         315.166667               0.364167
# 1215                         209.875000               0.501250
# 1228                         192.900000               0.376000
# 1221                         249.333333               0.411111
# 1229                         462.555556               0.373333
#
#       team1_PStat_lag64_W_PCT  team1_PStat_lag64_W_PCT_RANK  team1_W  \
# 0                    0.191667                    314.833333      1.0
# 1                    0.402750                    229.250000      1.0
# 12                   0.125000                    308.500000      0.0
# 11                   0.775000                     75.500000      1.0
# 10                   0.552250                    163.750000      0.0
# ...                       ...                           ...      ...
# 1216                 0.259083                    389.000000      0.0
# 1215                 0.505250                    245.875000      1.0
# 1228                 0.705100                    103.400000      0.0
# 1221                 0.585556                    200.777778      1.0
# 1229                 0.129222                    451.333333      0.0
#
#       team1_W_cum  team1_lag08_AST  team1_lag08_FG_PCT  \
# 0             0.0             0.46               0.451
# 1             0.0             0.29               0.349
# 12            0.0             0.42               0.381
# 11            0.0             0.36               0.456
# 10            0.0             0.46               0.475
# ...           ...              ...                 ...
# 1216          1.0             0.58               0.514
# 1215          2.0             0.51               0.446
# 1228          2.0             0.60               0.465
# 1221          1.0             0.60               0.506
# 1229          0.0             0.50               0.428
#
#       team1_lag08_PLUS_MINUS  team1_lag08_PLUS_MINUS_RANK  team1_lag08_PTS  \
# 0                       0.27                          6.0             2.29
# 1                      -0.83                         30.0             1.65
# 12                     -0.56                         27.0             2.02
# 11                     -0.11                         13.0             2.00
# 10                      0.27                          6.0             2.00
# ...                      ...                          ...              ...
# 1216                   -0.12                         22.0             2.35
# 1215                    0.15                          9.0             2.40
# 1228                   -0.07                         19.0             2.30
# 1221                    0.40                          1.0             2.61
# 1229                   -0.53                         30.0             1.95
#
#       team1_lag08_PTS_RANK  team1_lag08_W_PCT  team1_lag08_W_PCT_RANK  \
# 0                      7.0               1.00                     1.0
# 1                     30.0               0.00                    18.0
# 12                    22.0               0.00                    18.0
# 11                    18.0               0.00                    13.0
# 10                    18.0               1.00                     1.0
# ...                    ...                ...                     ...
# 1216                  20.0               0.40                    20.0
# 1215                  14.0               0.75                     6.0
# 1228                  24.0               0.40                    20.0
# 1221                   4.0               1.00                     1.0
# 1229                  30.0               0.00                    27.0
#
#       team1_lag16_AST  team1_lag16_BLK  team1_lag16_FG_PCT  \
# 0                0.46             0.13               0.451
# 1                0.29             0.06               0.349
# 12               0.42             0.02               0.381
# 11               0.36             0.08               0.456
# 10               0.46             0.06               0.475
# ...               ...              ...                 ...
# 1216             0.58             0.10               0.499
# 1215             0.53             0.14               0.462
# 1228             0.57             0.07               0.481
# 1221             0.53             0.12               0.488
# 1229             0.52             0.08               0.440
#
#       team1_lag16_PLUS_MINUS  team1_lag16_PLUS_MINUS_RANK  team1_lag16_PTS  \
# 0                       0.27                          6.0             2.29
# 1                      -0.83                         30.0             1.65
# 12                     -0.56                         27.0             2.02
# 11                     -0.11                         13.0             2.00
# 10                      0.27                          6.0             2.00
# ...                      ...                          ...              ...
# 1216                   -0.05                         20.0             2.31
# 1215                    0.11                         10.0             2.39
# 1228                    0.02                         14.0             2.38
# 1221                    0.15                          7.0             2.49
# 1229                   -0.40                         30.0             2.08
#
#       team1_lag16_PTS_RANK  team1_lag16_W_PCT  team1_lag16_W_PCT_RANK  \
# 0                      7.0              1.000                     1.0
# 1                     30.0              0.000                    18.0
# 12                    22.0              0.000                    18.0
# 11                    18.0              0.000                    13.0
# 10                    18.0              1.000                     1.0
# ...                    ...                ...                     ...
# 1216                  21.0              0.500                    18.0
# 1215                  15.0              0.625                     9.0
# 1228                  18.0              0.625                     9.0
# 1221                   6.0              0.714                     6.0
# 1229                  30.0              0.000                    29.0
#
#       team1_lag180_AST  team1_lag180_BLK  team1_lag180_DREB  \
# 0                 0.46              0.10               0.72
# 1                 0.59              0.14               0.72
# 12                0.48              0.08               0.68
# 11                0.53              0.10               0.69
# 10                0.46              0.09               0.66
# ...                ...               ...                ...
# 1216              0.52              0.10               0.71
# 1215              0.52              0.11               0.71
# 1228              0.57              0.09               0.74
# 1221              0.50              0.10               0.72
# 1229              0.48              0.09               0.68
#
#       team1_lag180_FG_PCT  team1_lag180_PLUS_MINUS  \
# 0                   0.451                     0.04
# 1                   0.498                     0.07
# 12                  0.448                    -0.06
# 11                  0.475                     0.04
# 10                  0.452                    -0.13
# ...                   ...                      ...
# 1216                0.472                    -0.07
# 1215                0.473                     0.01
# 1228                0.486                     0.16
# 1221                0.457                    -0.01
# 1229                0.443                    -0.18
#
#       team1_lag180_PLUS_MINUS_RANK  team1_lag180_PTS  team1_lag180_PTS_RANK  \
# 0                             13.0              2.15                   23.0
# 1                              6.0              2.32                    1.0
# 12                            22.0              2.13                   26.0
# 11                            12.0              2.29                    8.0
# 10                            28.0              2.07                   30.0
# ...                            ...               ...                    ...
# 1216                          23.0              2.25                   22.0
# 1215                          15.0              2.34                    9.0
# 1228                           1.0              2.39                    4.0
# 1221                          20.0              2.24                   23.0
# 1229                          30.0              2.21                   26.0
#
#       team1_lag180_TOV  team1_lag180_W_PCT  team1_lag180_W_PCT_RANK  \
# 0                 0.29               0.600                      9.0
# 1                 0.31               0.673                      3.0
# 12                0.24               0.304                     26.0
# 11                0.30               0.561                     15.0
# 10                0.27               0.333                     23.0
# ...                ...                 ...                      ...
# 1216              0.27               0.432                     21.0
# 1215              0.29               0.531                     14.0
# 1228              0.27               0.790                      1.0
# 1221              0.29               0.506                     18.0
# 1229              0.30               0.333                     25.0
#
#       team1_lag32_AST  team1_lag32_BLK  team1_lag32_FG_PCT  \
# 0                0.46             0.13               0.451
# 1                0.29             0.06               0.349
# 12               0.42             0.02               0.381
# 11               0.36             0.08               0.456
# 10               0.46             0.06               0.475
# ...               ...              ...                 ...
# 1216             0.56             0.10               0.485
# 1215             0.56             0.13               0.500
# 1228             0.58             0.09               0.496
# 1221             0.52             0.12               0.465
# 1229             0.50             0.09               0.442
#
#       team1_lag32_PLUS_MINUS  team1_lag32_PLUS_MINUS_RANK  team1_lag32_PTS  \
# 0                       0.27                          6.0             2.29
# 1                      -0.83                         30.0             1.65
# 12                     -0.56                         27.0             2.02
# 11                     -0.11                         13.0             2.00
# 10                      0.27                          6.0             2.00
# ...                      ...                          ...              ...
# 1216                   -0.11                         23.0             2.30
# 1215                    0.16                          4.0             2.49
# 1228                    0.16                          5.0             2.46
# 1221                   -0.02                         19.0             2.32
# 1229                   -0.38                         30.0             2.16
#
#       team1_lag32_PTS_RANK  team1_lag32_TOV  team1_lag32_W_PCT  \
# 0                      7.0             0.29              1.000
# 1                     30.0             0.33              0.000
# 12                    22.0             0.17              0.000
# 11                    18.0             0.28              0.000
# 10                    18.0             0.23              1.000
# ...                    ...              ...                ...
# 1216                  20.0             0.26              0.333
# 1215                   4.0             0.30              0.688
# 1228                   8.0             0.27              0.765
# 1221                  19.0             0.25              0.467
# 1229                  29.0             0.33              0.118
#
#       team1_lag32_W_PCT_RANK  team1_lag64_AST  team1_lag64_BLK  \
# 0                        1.0             0.51             0.09
# 1                       18.0             0.53             0.08
# 12                      18.0             0.48             0.07
# 11                      13.0             0.50             0.11
# 10                       1.0             0.42             0.07
# ...                      ...              ...              ...
# 1216                    23.0             0.55             0.10
# 1215                     5.0             0.52             0.11
# 1228                     3.0             0.60             0.10
# 1221                    19.0             0.52             0.12
# 1229                    30.0             0.49             0.08
#
#       team1_lag64_FG_PCT  team1_lag64_PLUS_MINUS  team1_lag64_PLUS_MINUS_RANK  \
# 0                  0.447                   -0.07                         21.0
# 1                  0.467                   -0.26                         27.0
# 12                 0.419                   -0.26                         28.0
# 11                 0.461                    0.12                          9.0
# 10                 0.451                    0.01                         13.0
# ...                  ...                     ...                          ...
# 1216               0.484                   -0.09                         21.0
# 1215               0.474                   -0.01                         18.0
# 1228               0.497                    0.16                          3.0
# 1221               0.469                   -0.01                         19.0
# 1229               0.433                   -0.35                         30.0
#
#       team1_lag64_PTS  team1_lag64_PTS_RANK  team1_lag64_STL  team1_lag64_TOV  \
# 0                2.11                  24.0             0.19             0.33
# 1                2.20                  14.0             0.13             0.31
# 12               2.03                  27.0             0.12             0.22
# 11               2.17                  15.0             0.09             0.23
# 10               1.91                  30.0             0.13             0.27
# ...               ...                   ...              ...              ...
# 1216             2.29                  24.0             0.14             0.27
# 1215             2.37                  12.0             0.15             0.29
# 1228             2.45                   4.0             0.18             0.26
# 1221             2.31                  21.0             0.15             0.27
# 1229             2.15                  30.0             0.18             0.32
#
#       team1_lag64_W_PCT  team1_lag64_W_PCT_RANK  team2_L_cum  \
# 0                 0.400                    19.0          0.0
# 1                 0.250                    24.0          0.0
# 12                0.000                    28.0          0.0
# 11                0.750                     5.0          0.0
# 10                0.667                     9.0          0.0
# ...                 ...                     ...          ...
# 1216              0.367                    23.0          1.0
# 1215              0.467                    17.0          2.0
# 1228              0.767                     2.0          2.0
# 1221              0.519                    15.0          1.0
# 1229              0.207                    29.0          0.0
#
#       team2_PStat_lag08_AST  team2_PStat_lag08_FG3M  team2_PStat_lag08_FG_PCT  \
# 0                  0.164444                0.046667                  0.428111
# 1                  0.095556                0.090000                  0.580111
# 12                 0.050000                0.041250                  0.346625
# 11                 0.070000                0.026000                  0.443900
# 10                 0.079000                0.034000                  0.361600
# ...                     ...                     ...                       ...
# 1216               0.130714                0.040714                  0.486571
# 1215               0.145556                0.052222                  0.482667
# 1228               0.093000                0.038000                  0.455200
# 1221               0.090000                0.030000                  0.418500
# 1229               0.092500                0.045000                  0.455500
#
#       team2_PStat_lag08_FG_PCT_RANK  team2_PStat_lag08_PLUS_MINUS  \
# 0                        138.666667                      0.650000
# 1                         89.888889                      0.198889
# 12                       260.000000                     -0.220000
# 11                       160.800000                     -0.216000
# 10                       164.300000                     -0.248000
# ...                             ...                           ...
# 1216                     167.857143                     -0.385000
# 1215                     189.222222                     -0.174444
# 1228                     219.600000                     -0.248000
# 1221                     241.666667                     -0.278333
# 1229                     190.166667                      0.565833
#
#       team2_PStat_lag08_PLUS_MINUS_RANK  team2_PStat_lag08_PTS  \
# 0                             42.888889               0.488889
# 1                            132.444444               0.537778
# 12                           240.500000               0.340000
# 11                           200.500000               0.536000
# 10                           172.500000               0.361000
# ...                                 ...                    ...
# 1216                         256.928571               0.437143
# 1215                         263.444444               0.498889
# 1228                         286.900000               0.441000
# 1221                         295.000000               0.366667
# 1229                          87.333333               0.393333
#
#       team2_PStat_lag08_W_PCT  team2_PStat_lag08_W_PCT_RANK  \
# 0                    1.000000                      1.000000
# 1                    0.777778                     74.444444
# 12                   0.375000                    197.500000
# 11                   0.200000                    163.800000
# 10                   0.200000                    105.000000
# ...                       ...                           ...
# 1216                 0.595286                    150.142857
# 1215                 0.000000                    338.000000
# 1228                 0.225000                    306.500000
# 1221                 0.311000                    281.833333
# 1229                 0.624917                    145.916667
#
#       team2_PStat_lag16_AST  team2_PStat_lag16_FG3M  team2_PStat_lag16_FG_PCT  \
# 0                  0.176667                0.048889                  0.443444
# 1                  0.088889                0.094444                  0.648556
# 12                 0.051250                0.022500                  0.365125
# 11                 0.071000                0.031000                  0.441400
# 10                 0.079000                0.034000                  0.361600
# ...                     ...                     ...                       ...
# 1216               0.127857                0.038571                  0.456429
# 1215               0.132222                0.048889                  0.467222
# 1228               0.084000                0.036000                  0.444000
# 1221               0.091667                0.030000                  0.429167
# 1229               0.080000                0.051667                  0.459583
#
#       team2_PStat_lag16_FG_PCT_RANK  team2_PStat_lag16_NBA_FANTASY_PTS  \
# 0                        124.666667                           1.271111
# 1                         50.222222                           0.955556
# 12                       287.500000                           0.722500
# 11                       179.600000                           1.027000
# 10                       164.300000                           0.808000
# ...                             ...                                ...
# 1216                     190.214286                           0.906429
# 1215                     211.000000                           0.987778
# 1228                     255.000000                           0.859000
# 1221                     244.666667                           0.810000
# 1229                     211.666667                           0.899167
#
#       team2_PStat_lag16_NBA_FANTASY_PTS_RANK  team2_PStat_lag16_PLUS_MINUS  \
# 0                                  61.444444                      0.661111
# 1                                 125.222222                      0.266667
# 12                                270.750000                     -0.512500
# 11                                134.500000                     -0.183000
# 10                                150.900000                     -0.248000
# ...                                      ...                           ...
# 1216                              195.785714                     -0.317143
# 1215                              170.666667                     -0.287778
# 1228                              239.400000                     -0.189000
# 1221                              261.333333                     -0.288333
# 1229                              219.333333                      0.196667
#
#       team2_PStat_lag16_PLUS_MINUS_RANK  team2_PStat_lag16_PTS  \
# 0                             42.888889               0.507778
# 1                            115.222222               0.581111
# 12                           309.875000               0.368750
# 11                           201.700000               0.534000
# 10                           172.500000               0.361000
# ...                                 ...                    ...
# 1216                         244.642857               0.415714
# 1215                         327.222222               0.490000
# 1228                         304.200000               0.428000
# 1221                         331.666667               0.373333
# 1229                         138.666667               0.410000
#
#       team2_PStat_lag16_W_PCT  team2_PStat_lag16_W_PCT_RANK  \
# 0                    1.000000                      1.000000
# 1                    0.805556                     80.888889
# 12                   0.243750                    270.750000
# 11                   0.175000                    179.400000
# 10                   0.200000                    105.000000
# ...                       ...                           ...
# 1216                 0.679000                    134.142857
# 1215                 0.000000                    378.000000
# 1228                 0.383200                    289.100000
# 1221                 0.302667                    315.833333
# 1229                 0.449667                    255.166667
#
#       team2_PStat_lag180_AST  team2_PStat_lag180_FG3M  \
# 0                   0.132222                 0.041111
# 1                   0.074444                 0.047778
# 12                  0.072500                 0.051250
# 11                  0.074000                 0.040000
# 10                  0.101000                 0.035000
# ...                      ...                      ...
# 1216                0.092857                 0.046429
# 1215                0.118889                 0.047778
# 1228                0.080000                 0.045000
# 1221                0.076667                 0.031667
# 1229                0.075000                 0.052500
#
#       team2_PStat_lag180_FG3_PCT  team2_PStat_lag180_FG_PCT  \
# 0                       0.302222                   0.464556
# 1                       0.276333                   0.465889
# 12                      0.294750                   0.445500
# 11                      0.277100                   0.480800
# 10                      0.259100                   0.462600
# ...                          ...                        ...
# 1216                    0.301571                   0.451929
# 1215                    0.327889                   0.467667
# 1228                    0.293900                   0.439000
# 1221                    0.269667                   0.425333
# 1229                    0.275583                   0.445417
#
#       team2_PStat_lag180_FG_PCT_RANK  team2_PStat_lag180_NBA_FANTASY_PTS  \
# 0                         222.888889                            0.985556
# 1                         249.111111                            0.864444
# 12                        297.000000                            0.830000
# 11                        197.900000                            0.937000
# 10                        248.100000                            0.904000
# ...                              ...                                 ...
# 1216                      252.571429                            0.853571
# 1215                      264.777778                            0.952222
# 1228                      333.200000                            0.866000
# 1221                      311.500000                            0.770000
# 1229                      319.666667                            0.858333
#
#       team2_PStat_lag180_NBA_FANTASY_PTS_RANK  team2_PStat_lag180_PLUS_MINUS  \
# 0                                  183.333333                       0.092222
# 1                                  238.555556                      -0.014444
# 12                                 261.375000                      -0.118750
# 11                                 199.400000                       0.033000
# 10                                 211.000000                       0.053000
# ...                                       ...                            ...
# 1216                               263.928571                      -0.219286
# 1215                               215.444444                      -0.126667
# 1228                               277.300000                      -0.124000
# 1221                               368.666667                      -0.353333
# 1229                               291.416667                       0.040833
#
#       team2_PStat_lag180_PLUS_MINUS_RANK  team2_PStat_lag180_PTS  \
# 0                             126.111111                0.445556
# 1                             250.555556                0.403333
# 12                            329.125000                0.453750
# 11                            197.300000                0.514000
# 10                            156.800000                0.420000
# ...                                  ...                     ...
# 1216                          288.142857                0.415714
# 1215                          421.444444                0.457778
# 1228                          416.600000                0.421000
# 1221                          520.000000                0.355000
# 1229                          206.666667                0.399167
#
#       team2_PStat_lag180_W_PCT  team2_PStat_lag180_W_PCT_RANK  \
# 0                     0.735000                      57.888889
# 1                     0.549000                     184.666667
# 12                    0.400500                     330.750000
# 11                    0.541000                     230.800000
# 10                    0.684100                      96.200000
# ...                        ...                            ...
# 1216                  0.566929                     246.000000
# 1215                  0.252889                     515.888889
# 1228                  0.330100                     472.000000
# 1221                  0.306000                     442.500000
# 1229                  0.589583                     203.750000
#
#       team2_PStat_lag32_AST  team2_PStat_lag32_FG3M  \
# 0                  0.164444                0.046667
# 1                  0.092222                0.095556
# 12                 0.050000                0.026250
# 11                 0.074000                0.020000
# 10                 0.079000                0.034000
# ...                     ...                     ...
# 1216               0.120714                0.040714
# 1215               0.137778                0.048889
# 1228               0.079000                0.042000
# 1221               0.086667                0.031667
# 1229               0.075833                0.054167
#
#       team2_PStat_lag32_FG3_PCT  team2_PStat_lag32_FG_PCT  \
# 0                      0.260667                  0.428111
# 1                      0.403556                  0.577778
# 12                     0.172750                  0.367000
# 11                     0.148600                  0.419300
# 10                     0.302500                  0.361600
# ...                         ...                       ...
# 1216                   0.210714                  0.468000
# 1215                   0.327444                  0.469222
# 1228                   0.308400                  0.452500
# 1221                   0.267167                  0.428500
# 1229                   0.276083                  0.455917
#
#       team2_PStat_lag32_FG_PCT_RANK  team2_PStat_lag32_NBA_FANTASY_PTS  \
# ...
# 11                   0.201100                    299.800000          0.0
# 10                   0.800000                     60.200000          0.0
# ...                       ...                           ...          ...
# 1216                 0.569143                    206.357143          2.0
# 1215                 0.174444                    439.666667          0.0
# 1228                 0.344600                    358.300000          1.0
# 1221                 0.267333                    389.333333          1.0
# 1229                 0.594167                    183.333333          3.0
#
#       team2_lag08_AST  team2_lag08_DREB  team2_lag08_FG_PCT  \
# 0                0.73              0.83               0.495
# 1                0.67              0.77               0.553
# 12               0.73              0.85               0.632
# 11               0.56              0.69               0.494
# 10               0.38              0.81               0.371
# ...               ...               ...                 ...
# 1216             0.68              0.65               0.534
# 1215             0.60              0.62               0.497
# 1228             0.52              0.70               0.463
# 1221             0.50              0.73               0.453
# 1229             0.46              0.77               0.454
#
#       team2_lag08_PLUS_MINUS  team2_lag08_PLUS_MINUS_RANK  team2_lag08_PTS  \
# 0                       0.73                          1.0             2.71
# 1                       0.29                          5.0             2.85
# 12                      0.56                          2.0             2.58
# 11                     -0.31                         21.0             2.08
# 10                     -0.19                         15.0             1.94
# ...                      ...                          ...              ...
# 1216                   -0.08                         20.0             2.55
# 1215                   -0.16                         24.0             2.51
# 1228                   -0.24                         27.0             2.18
# 1221                   -0.16                         25.0             2.16
# 1229                    0.16                          8.0             2.39
#
#       team2_lag08_PTS_RANK  team2_lag08_REB  team2_lag08_W_PCT  \
# 0                      2.0             1.19               1.00
# 1                      1.0             0.94               1.00
# 12                     3.0             0.96               1.00
# 11                    13.0             0.85               0.00
# 10                    21.0             1.10               0.00
# ...                    ...              ...                ...
# 1216                   7.0             0.82               0.50
# 1215                   8.0             0.87               0.00
# 1228                  27.0             0.82               0.25
# 1221                  28.0             0.96               0.40
# 1229                  16.0             1.05               0.50
#
#       team2_lag08_W_PCT_RANK  team2_lag16_AST  team2_lag16_DREB  \
# 0                        1.0             0.73              0.83
# 1                        1.0             0.67              0.77
# 12                       1.0             0.73              0.85
# 11                      13.0             0.56              0.69
# 10                      13.0             0.38              0.81
# ...                      ...              ...               ...
# 1216                    13.0             0.66              0.66
# 1215                    27.0             0.57              0.54
# 1228                    23.0             0.49              0.68
# 1221                    20.0             0.54              0.71
# 1229                    13.0             0.48              0.69
#
#       team2_lag16_FG_PCT  team2_lag16_PLUS_MINUS  team2_lag16_PLUS_MINUS_RANK  \
# 0                  0.495                    0.73                          1.0
# 1                  0.553                    0.29                          5.0
# 12                 0.632                    0.56                          2.0
# 11                 0.494                   -0.31                         21.0
# 10                 0.371                   -0.19                         15.0
# ...                  ...                     ...                          ...
# 1216               0.505                    0.02                         16.0
# 1215               0.475                   -0.30                         29.0
# 1228               0.457                   -0.18                         27.0
# 1221               0.467                   -0.15                         24.0
# 1229               0.473                    0.05                         13.0
#
#       team2_lag16_PTS  team2_lag16_PTS_RANK  team2_lag16_REB  \
# 0                2.71                   2.0             1.19
# 1                2.85                   1.0             0.94
# 12               2.58                   3.0             0.96
# 11               2.08                  13.0             0.85
# 10               1.94                  21.0             1.10
# ...               ...                   ...              ...
# 1216             2.47                   8.0             0.87
# 1215             2.39                  16.0             0.78
# 1228             2.21                  28.0             0.86
# 1221             2.25                  25.0             0.92
# 1229             2.33                  20.0             0.93
#
#       team2_lag16_W_PCT  team2_lag16_W_PCT_RANK  team2_lag180_AST  \
# 0                 1.000                     1.0              0.57
# 1                 1.000                     1.0              0.44
# 12                1.000                     1.0              0.45
# 11                0.000                    13.0              0.48
# 10                0.000                    13.0              0.47
# ...                 ...                     ...               ...
# 1216              0.625                     9.0              0.58
# 1215              0.000                    29.0              0.52
# 1228              0.429                    20.0              0.49
# 1221              0.375                    21.0              0.46
# 1229              0.375                    21.0              0.47
#
#       team2_lag180_DREB  team2_lag180_FG_PCT  team2_lag180_FT_PCT  \
# 0                  0.75                0.479                0.762
# 1                  0.68                0.459                0.714
# 12                 0.70                0.439                0.735
# 11                 0.72                0.479                0.740
# 10                 0.74                0.465                0.764
# ...                 ...                  ...                  ...
# 1216               0.70                0.467                0.741
# 1215               0.68                0.463                0.769
# 1228               0.69                0.459                0.769
# 1221               0.73                0.430                0.757
# 1229               0.74                0.471                0.768
#
#       team2_lag180_PLUS_MINUS  team2_lag180_PLUS_MINUS_RANK  team2_lag180_PTS  \
# 0                        0.13                           3.0              2.29
# 1                        0.07                           5.0              2.28
# 12                      -0.21                          30.0              2.13
# 11                       0.02                          15.0              2.30
# 10                       0.09                           4.0              2.17
# ...                       ...                           ...               ...
# 1216                     0.01                          17.0              2.38
# 1215                    -0.07                          24.0              2.29
# 1228                    -0.12                          25.0              2.28
# 1221                    -0.16                          26.0              2.15
# 1229                     0.12                           4.0              2.36
#
#       team2_lag180_PTS_RANK  team2_lag180_REB  team2_lag180_TOV  \
# 0                       7.0              0.97              0.33
# 1                      11.0              0.94              0.28
# 12                     27.0              0.90              0.32
# 11                      5.0              0.92              0.30
# 10                     17.0              0.93              0.30
# ...                     ...               ...               ...
# 1216                    5.0              0.92              0.27
# 1215                   13.0              0.91              0.30
# 1228                   16.0              0.89              0.29
# 1221                   30.0              0.95              0.29
# 1229                    7.0              0.96              0.29
#
#       team2_lag180_W_PCT  team2_lag180_W_PCT_RANK  team2_lag32_AST  \
# 0                  0.672                      4.0             0.73
# 1                  0.638                      5.0             0.67
# 12                 0.218                     30.0             0.73
# 11                 0.576                     11.0             0.56
# 10                 0.625                      6.0             0.38
# ...                  ...                      ...              ...
# 1216               0.519                     16.0             0.65
# 1215               0.309                     26.0             0.59
# 1228               0.358                     24.0             0.51
# 1221               0.296                     27.0             0.52
# 1229               0.593                      9.0             0.46
#
#       team2_lag32_DREB  team2_lag32_FG_PCT  team2_lag32_PLUS_MINUS  \
# 0                 0.83               0.495                    0.73
# 1                 0.77               0.553                    0.29
# 12                0.85               0.632                    0.56
# 11                0.69               0.494                   -0.31
# 10                0.81               0.371                   -0.19
# ...                ...                 ...                     ...
# 1216              0.66               0.504                    0.05
# 1215              0.59               0.483                   -0.16
# 1228              0.66               0.463                   -0.16
# 1221              0.71               0.462                   -0.19
# 1229              0.72               0.467                    0.10
#
#       team2_lag32_PLUS_MINUS_RANK  team2_lag32_PTS  team2_lag32_PTS_RANK  \
# 0                             1.0             2.71                   2.0
# 1                             5.0             2.85                   1.0
# 12                            2.0             2.58                   3.0
# 11                           21.0             2.08                  13.0
# 10                           15.0             1.94                  21.0
# ...                           ...              ...                   ...
# 1216                         13.0             2.48                   5.0
# 1215                         25.0             2.43                   9.0
# 1228                         26.0             2.27                  27.0
# 1221                         28.0             2.29                  22.0
# 1229                          7.0             2.36                  17.0
#
#       team2_lag32_REB  team2_lag32_W_PCT  team2_lag32_W_PCT_RANK  \
# 0                1.19              1.000                     1.0
# 1                0.94              1.000                     1.0
# 12               0.96              1.000                     1.0
# 11               0.85              0.000                    13.0
# 10               1.10              0.000                    13.0
# ...               ...                ...                     ...
# 1216             0.87              0.625                     9.0
# 1215             0.84              0.200                    29.0
# 1228             0.83              0.357                    21.0
# 1221             0.92              0.235                    27.0
# 1229             0.96              0.471                    18.0
#
#       team2_lag64_AST  team2_lag64_DREB  team2_lag64_FG_PCT  \
# 0                0.68              0.82               0.497
# 1                0.51              0.69               0.459
# 12               0.55              0.78               0.473
# 11               0.52              0.67               0.473
# 10               0.55              0.77               0.484
# ...               ...               ...                 ...
# 1216             0.61              0.69               0.478
# 1215             0.56              0.63               0.475
# 1228             0.51              0.69               0.472
# 1221             0.50              0.72               0.451
# 1229             0.48              0.73               0.470
#
#       team2_lag64_FT_PCT  team2_lag64_PLUS_MINUS  team2_lag64_PLUS_MINUS_RANK  \
# 0                  0.707                    0.27                          5.0
# 1                  0.777                    0.29                          4.0
# 12                 0.746                   -0.06                         20.0
# 11                 0.596                   -0.36                         29.0
# 10                 0.724                    0.35                          3.0
# ...                  ...                     ...                          ...
# 1216               0.749                    0.02                         15.0
# 1215               0.778                   -0.13                         26.0
# 1228               0.791                   -0.13                         24.0
# 1221               0.742                   -0.19                         29.0
# 1229               0.751                    0.12                          5.0
#
#       team2_lag64_PTS  team2_lag64_PTS_RANK  team2_lag64_REB  \
# 0                2.53                   2.0             1.05
# 1                2.50                   4.0             0.90
# 12               2.27                   9.0             0.96
# 11               2.14                  22.0             0.93
# 10               2.30                   8.0             0.99
# ...               ...                   ...              ...
# 1216             2.40                  10.0             0.92
# 1215             2.39                  11.0             0.88
# 1228             2.31                  18.0             0.86
# 1221             2.24                  28.0             0.93
# 1229             2.36                  13.0             0.97
#
#       team2_lag64_W_PCT  team2_lag64_W_PCT_RANK  SEASON  DATE_WITHIN_SEASON
# 0                 1.000                     1.0      22                 0.0
# 1                 1.000                     1.0      22                 0.0
# 12                0.333                    23.0      22                 1.0
# 11                0.000                    28.0      22                 1.0
# 10                0.750                     5.0      22                 1.0
# ...                 ...                     ...     ...                 ...
# 1216              0.483                    16.0      28               173.0
# 1215              0.214                    28.0      28               173.0
# 1228              0.370                    22.0      28               173.0
# 1221              0.258                    26.0      28               173.0
# 1229              0.586                    11.0      28               173.0
#
# [4599 rows x 212 columns]
